# %% [markdown]
# # Xceptionの概要
# Xception(Xetreme Inception)はGoogLeNetの改良版で, Iamge Net dataset(ILSVRCのデータ)でerror率5.5%のモデルである. GoogLeNetで用いられたInceptionはチャネルを分割してConvolutionに入力していた. これは空間情報と深さ(チャネル)情報がある程度分離して扱えることを意味している(Inception仮説). XceptionはInceptionの"ある程度"の分離を完全(Extreme)に分離する手法を採用している. これによって通常のConvolutionモデルと比較して約1/10のパラメータ数を実現している.
#
# Xceptionモデルは次に示すようなモデルである(論文から引用). ここで各Separatable Convは次に示すような構造をしている.
#
# ![Xception-Architecture](./Xception-Architecture.png)
#
#
# ![Separatable-Conv](./Separatable-Conv.png)

# %% [markdown]
# # CIFAR-10による検証(転移学習)
# Xceptionモデルを用いてCIFAR-10の転移学習を行う.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# load CIFAR-10
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.astype('float32') / 255
y_train = to_categorical(y_train)

x_test = x_test.astype('float32') / 255
y_test = to_categorical(y_test)

x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=10000)

# %%
import keras
import tensorflow as tf
from IPython.display import SVG
from tensorflow.python.keras.utils.vis_utils import model_to_dot
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D,Input

# base model(Xception)を読み込み
# include_top : 出力層側の3つのDenseを含むかどうか
base_model =  tf.keras.applications.xception.Xception(weights='imagenet',include_top=False,input_tensor=Input(shape=(224,224,3)))

# base modelに出力層を追加
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024,activation="relu")(x)
prediction=Dense(10,activation='softmax')(x)
model=Model(inputs=base_model.input,outputs=prediction)
    
model.compile(
    loss=keras.losses.categorical_crossentropy,
    optimizer="adam",
    metrics=["accuracy"]
)

# %%
SVG(model_to_dot(model, show_shapes=True, dpi=None).create(prog='dot', format='svg'))

# %%
# モデルを画像として出力
from keras.utils import plot_model
plot_model(model,show_shapes=True,to_file='Xception.png')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen=ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

validation_datagen=ImageDataGenerator()

train_datagen.fit(x_train)
validation_datagen.fit(x_valid)

train_generator=train_datagen.flow(
    x_train,y_train,
    batch_size=100,
    shuffle=True
)

validation_generator=validation_datagen.flow(
    x_valid,y_valid,
    batch_size=100,
    shuffle=True
)

hist=model.fit_generator(train_generator,
                         epochs=50,
                         verbose=1,
                         validation_data=validation_generator)
# Out:
# C:\Users\yudai\anaconda3\envs\py38-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 400/400 [==============================] - 253s 617ms/step - loss: 1.6267 - accuracy: 0.4182 - val_loss: 1.0942 - val_accuracy: 0.6879
# Epoch 2/50
# 400/400 [==============================] - 156s 389ms/step - loss: 0.7335 - accuracy: 0.7617 - val_loss: 0.6206 - val_accuracy: 0.7924
# Epoch 3/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.5999 - accuracy: 0.8024 - val_loss: 0.7314 - val_accuracy: 0.7693
# Epoch 4/50
# 400/400 [==============================] - 23s 56ms/step - loss: 0.5142 - accuracy: 0.8303 - val_loss: 0.5479 - val_accuracy: 0.8199
# Epoch 5/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.4416 - accuracy: 0.8549 - val_loss: 0.5201 - val_accuracy: 0.8236
# Epoch 6/50
# 400/400 [==============================] - 23s 56ms/step - loss: 0.4031 - accuracy: 0.8638 - val_loss: 0.6515 - val_accuracy: 0.8022
# Epoch 7/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.3653 - accuracy: 0.8798 - val_loss: 0.5901 - val_accuracy: 0.8088
# Epoch 8/50
# 400/400 [==============================] - 22s 56ms/step - loss: 0.3345 - accuracy: 0.8863 - val_loss: 0.4799 - val_accuracy: 0.8472
# Epoch 9/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.3085 - accuracy: 0.8982 - val_loss: 0.4824 - val_accuracy: 0.8427
# Epoch 10/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.2918 - accuracy: 0.9011 - val_loss: 0.5336 - val_accuracy: 0.8303
# Epoch 11/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.2583 - accuracy: 0.9117 - val_loss: 0.5057 - val_accuracy: 0.8412
# Epoch 12/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.2313 - accuracy: 0.9223 - val_loss: 0.4704 - val_accuracy: 0.8515
# Epoch 13/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.2130 - accuracy: 0.9291 - val_loss: 0.5070 - val_accuracy: 0.8452
# Epoch 14/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.2101 - accuracy: 0.9294 - val_loss: 2.7083 - val_accuracy: 0.7115
# Epoch 15/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.2538 - accuracy: 0.9175 - val_loss: 0.4792 - val_accuracy: 0.8590
# Epoch 16/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.1846 - accuracy: 0.9382 - val_loss: 0.4963 - val_accuracy: 0.8593
# Epoch 17/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.1994 - accuracy: 0.9358 - val_loss: 0.5599 - val_accuracy: 0.8396
# Epoch 18/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.1587 - accuracy: 0.9462 - val_loss: 0.5173 - val_accuracy: 0.8528
# Epoch 19/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.1438 - accuracy: 0.9528 - val_loss: 0.5879 - val_accuracy: 0.8479
# Epoch 20/50
# 400/400 [==============================] - 23s 58ms/step - loss: 0.1357 - accuracy: 0.9537 - val_loss: 0.5200 - val_accuracy: 0.8535
# Epoch 21/50
# 400/400 [==============================] - 24s 59ms/step - loss: 0.1451 - accuracy: 0.9527 - val_loss: 0.5605 - val_accuracy: 0.8486
# Epoch 22/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.1227 - accuracy: 0.9604 - val_loss: 0.5496 - val_accuracy: 0.8597
# Epoch 23/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.1252 - accuracy: 0.9563 - val_loss: 0.5229 - val_accuracy: 0.8618
# Epoch 24/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.1163 - accuracy: 0.9601 - val_loss: 0.7660 - val_accuracy: 0.8537
# Epoch 25/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.1197 - accuracy: 0.9630 - val_loss: 1.2445 - val_accuracy: 0.7650
# Epoch 26/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.2178 - accuracy: 0.9278 - val_loss: 0.4903 - val_accuracy: 0.8644
# Epoch 27/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.1191 - accuracy: 0.9599 - val_loss: 0.5452 - val_accuracy: 0.8534
# Epoch 28/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.1013 - accuracy: 0.9662 - val_loss: 0.6967 - val_accuracy: 0.8707
# Epoch 29/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0924 - accuracy: 0.9688 - val_loss: 1.9921 - val_accuracy: 0.8151
# Epoch 30/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0988 - accuracy: 0.9657 - val_loss: 0.5239 - val_accuracy: 0.8668
# Epoch 31/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0799 - accuracy: 0.9725 - val_loss: 0.4967 - val_accuracy: 0.8739
# Epoch 32/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0811 - accuracy: 0.9718 - val_loss: 0.6057 - val_accuracy: 0.8544
# Epoch 33/50
# 400/400 [==============================] - 23s 58ms/step - loss: 0.0909 - accuracy: 0.9684 - val_loss: 0.4840 - val_accuracy: 0.8759
# Epoch 34/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0759 - accuracy: 0.9743 - val_loss: 0.5140 - val_accuracy: 0.8707
# Epoch 35/50
# 400/400 [==============================] - 23s 58ms/step - loss: 0.0782 - accuracy: 0.9746 - val_loss: 0.5564 - val_accuracy: 0.8620
# Epoch 36/50
# 400/400 [==============================] - 22s 56ms/step - loss: 0.0659 - accuracy: 0.9781 - val_loss: 0.5923 - val_accuracy: 0.8600
# Epoch 37/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0799 - accuracy: 0.9737 - val_loss: 0.5754 - val_accuracy: 0.8581
# Epoch 38/50
# 400/400 [==============================] - 23s 58ms/step - loss: 0.0730 - accuracy: 0.9744 - val_loss: 0.5706 - val_accuracy: 0.8678
# Epoch 39/50
# 400/400 [==============================] - 23s 58ms/step - loss: 0.0721 - accuracy: 0.9750 - val_loss: 0.5542 - val_accuracy: 0.8604
# Epoch 40/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0687 - accuracy: 0.9769 - val_loss: 0.5862 - val_accuracy: 0.8625
# Epoch 41/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0719 - accuracy: 0.9759 - val_loss: 0.5544 - val_accuracy: 0.8668
# Epoch 42/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0645 - accuracy: 0.9793 - val_loss: 8.9167 - val_accuracy: 0.7912
# Epoch 43/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0959 - accuracy: 0.9697 - val_loss: 0.6018 - val_accuracy: 0.8581
# Epoch 44/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0721 - accuracy: 0.9753 - val_loss: 0.5905 - val_accuracy: 0.8672
# Epoch 45/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0756 - accuracy: 0.9762 - val_loss: 0.5968 - val_accuracy: 0.8605
# Epoch 46/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0812 - accuracy: 0.9734 - val_loss: 0.5388 - val_accuracy: 0.8698
# Epoch 47/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0611 - accuracy: 0.9792 - val_loss: 0.5410 - val_accuracy: 0.8743
# Epoch 48/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0529 - accuracy: 0.9829 - val_loss: 0.5627 - val_accuracy: 0.8680
# Epoch 49/50
# 400/400 [==============================] - 23s 57ms/step - loss: 0.0528 - accuracy: 0.9823 - val_loss: 0.5349 - val_accuracy: 0.8723
# Epoch 50/50
# 400/400 [==============================] - 23s 58ms/step - loss: 0.0569 - accuracy: 0.9815 - val_loss: 0.5794 - val_accuracy: 0.8703

# %%
def plot_loss(history):
    """エポックごとの損失関数をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    # 損失関数の履歴を取得
    loss_train = history.history["loss"]
    loss_val = history.history["val_loss"]

    # 損失関数をプロット
    epochs=range(1,len(history.history["loss"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs,loss_train,label="Training loss")
    plt.plot(epochs,loss_val,label="Validation loss")
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
def plot_acc(history):
    """エポックごとの正解率をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    acc_train = history.history['accuracy']
    acc_val = history.history['val_accuracy']
    epochs = range(1,len(history.history["accuracy"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs, acc_train, 'g', label='Training accuracy')
    plt.plot(epochs, acc_val, 'b', label='Validation accuracy')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
# 損失関数の描画
plot_loss(hist)

# %%
# 正解率を描画
plot_acc(hist)

# %%
# modelの評価
test_datagen=ImageDataGenerator()
test_datagen.fit(x_test)
test_generator=test_datagen.flow(
    x_test,y_test,
    batch_size=100,
    shuffle=True
)

scores = model.evaluate(test_generator)
# Out:
# 100/100 [==============================] - 2s 17ms/step - loss: 0.5791 - accuracy: 0.8651
