# %% [markdown]
# # ResNetの概要
# ResNetはILSVRC-2015で1位のerror率3.57%のモデルである. これまでの経験から層を深くすると表現力が良くなり, 性能が良くなるということがわかっていた. しかし層が深すぎると最適化と近似計算の効率が良くならず, 浅いモデルのほうが性能が良くなってしまう現象(Degradation)が起きている. これを恒等写像の学習が難しいのではないか, という仮説の元, ResNetはResidual learningという手法を用いて恒等写像を基準に学習するモデルを採用した. またResNetの論文では初めてBatch NormalizationやHeの初期値についての記述がある.
#
# Residual blockは次に示すように, 2つのConv layer(weight layer)とshortcut connection(恒等写像)からなる層のことである(図は論文から引用). Conv layerとshortcut connectionの結合時にshapeが異なることがあるが, これはConv layerの結果を無理矢理shortcut connectionのshapeに合わせるか, Conv layerのチャンネル数とstrideを調整することで解決する. このResidual blockを用いてlayerを1つの単位としてlayerを構成する手法がResidual learningである.
#
# ![Residual learning](./Residual_learning.png)
#
# ResnetにはResNet-34, Resnet-152という代表的なモデルがある. ここでは両方のモデルを紹介するが, 実装はResNet-34のみとする.ResNet-34およびResNet-152のモデルを次に示す. どちらのモデルにおいても, 各Residual blockの最初の層は`Stride=2`, 他の層は`Stride=1`である.
#
# **ResNet-34**
#
#  <span style="color:green">Define of Redidual Block</span>
# 1. input
# 2. Conv (3,3)
# 3. Conv (3,3)
# 4. add Conv's output and shortcut connection
# 5. output
#
# <span style="color:green">Main model</span>
# - Input : (224,224,3)
#
#
# - Conv1
#     - Input (224,224,3)
#     - Filter : (7,7,64)
#     - Stride : 2
#
#
# - Max Pooling
#     - Filter : (3,3)
#     - Stride : 2
#     - Output : (56,56,64)
#
#
# - Residual block x3
#     - Channel : 64
#
#
# - Residual block x4
#     - Channel : 128
#
#
# - Residual block x6
#     - Channel : 256
#
#
# - Residual block x3
#     - Channel : 512
#
#
# - Global Average Pooling
#
#
# - Dense
#     - Activation Softmax
#     - Output : (1000)
#
#
# **ResNet-152**
#
#  <span style="color:green">Define of Redidual Block</span>
# 1. input
# 2. Conv1
# 3. Conv2
# 4. Conv3
# 5. add Conv's output and shortcut connection
# 6. output
#
# |Type|A|B|C|D|
# :-:|:-:|:-:|:-:|:-:
# |Conv1 : (1,1)|64|128|256|512|
# |Conv2 : (3,3)|64|128|256|512|
# |Conv3 : (1,1)|64|512|1024|2048|
#
# <span style="color:green">Main model</span>
# - Input : (224,224,3)
#
#
# - Conv1
#     - Input : (224,224,3)
#     - Filter : (7,7,256)
#     - Stride : 2
#
#
# - Max Pooling
#     - Filter : (3,3)
#     - Stride : 2
#     - Output : (56,56,256)
#
#
# - Res-A x3
#
#
# - Res-Bx8
#
#
# - Res-C x36
#
#
# - Res-D x3
#
#
# - Global Average Pooling
#     - Dense
#     - Activation : Softmax
#     - Output : (1000)
#
# Reference:
# Deep Residual Learning for Image Recognition
# https://openaccess.thecvf.com/content_cvpr_2016/papers/He_Deep_Residual_Learning_CVPR_2016_paper.pdf

# %% [markdown]
# # ResNet-34の実装

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import keras
import tensorflow
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, ReLU, BatchNormalization
from tensorflow.keras.layers import Add, GlobalAveragePooling2D
from IPython.display import SVG
from tensorflow.python.keras.utils.vis_utils import model_to_dot

# %% [markdown]
# ## ベースモデルの生成

# %%
def stem(inputs):
    """最初のConv,Pooling layerを追加する関数
    
    Args:
    inputs : 作成するモデル
    
    Returns:
    x : inputs modelにCov,Pooling layerを加えたモデル
    """
    
    x = Conv2D(64, kernel_size=(7, 7), activation="relu",strides=(2,2),padding="same",kernel_initializer=("he_normal"))(inputs)
    x = MaxPooling2D((3, 3), strides=(2, 2),padding="same")(x)
    return x

def learner(x):
    """residual learnig layerをまとめて追加する関数
    
    Args:
    x : 最初のConv,Poolingを追加したモデル
    
    Returns:
    x : residual learning layerを追加したモデル
    """
    # 64チャネルのresidual learnig layerを3つ追加
    x = residual_group(x,64,3)
    # 128チャネルのresidual learnig layerを4つ追加
    x = residual_group(x,128,3)
    # 256チャネルのresidual learnig layerを6つ追加
    x = residual_group(x,256,5)
    # 512チャネルのresidual learnig layerを3つ追加
    x = residual_group(x,512,2,False)
    return x

def residual_group(x,n_filters,n_blocks,conv=True):
    """residual learnig layerを追加する関数
    
    Args:
    x : residual leraning layerを追加するモデル
    n_filters : フィルターのチャネル数
    n_blocks : residual learingの層数
    conv : 畳み込み層を結合するかのフラグ
    
    Returns:
    x : residual learningを追加したモデル
    """
    for i in range(n_blocks): # nblock回iterate
        x = residual_block(x,n_filters) # residual blockを追加
        
    if conv:
        x = conv_block(x,n_filters*2)
    return x

def residual_block(x,n_filters):
    """residual blockを追加する関数
    
    Args:
    x : residual blockを追加するモデル
    n_filters : フィルターのチャネル数
    
    Returns:
    x : residual blockを追加したモデル
    """
    
    shortcut = x
    x = Conv2D(n_filters, (3, 3), strides=(1, 1), padding="same",activation="relu", kernel_initializer="he_normal")(x)
    x = Conv2D(n_filters, (3, 3), strides=(1, 1), padding="same",activation="relu", kernel_initializer="he_normal")(x)
    x = Add()([shortcut,x])
    return x

def conv_block(x,n_filters):
    """residual blockを追加する関数(Poolingなし)
    
    Args:
    x : residual blockを追加するモデル
    n_filters : フィルターのチャネル数
    
    Returns:
    x : residual blockを追加したモデル
    """
    shortcut = x
    x = Conv2D(n_filters, (3, 3), strides=(1, 1), padding="same",activation="relu", kernel_initializer="he_normal")(x)
    x = Conv2D(n_filters, (3, 3), strides=(1, 1), padding="same",activation="relu", kernel_initializer="he_normal")(x)
    return x   

def classifier(x,n_classes):
    """Global Average Pooling, Dense layerを追加する関数
    
    Args:
    x : Global Average Pooling, Dense layerを追加するモデル
    n_classes : 出力層の数
    
    Returns:
    outputs : Global Average Pooling, Dense layerを追加したモデル
    """
    
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(n_classes,activation="softmax",kernel_initializer="he_normal")(x)
    return outputs

# %%
inputs =  Input(shape=(224,224,3))
x = stem(inputs)
x = learner(x)
outputs = classifier(x, 1000)
model = Model(inputs, outputs)

SVG(model_to_dot(model, show_shapes=True, dpi=None).create(prog='dot', format='svg'))

# %%
# モデルを画像として出力
from keras.utils import plot_model
plot_model(model,show_shapes=True,to_file='ResNet-34.png')

# %% [markdown]
# ## CIFAR-10による検証
# CIFAR-10データを用いてResNetの精度検証を行う. 上のセルで作成したモデルの入力と,出力のサイズを調整することでCIFAR-10データに適応する.

# %%
# load CIFAR-10
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.astype('float32') / 255
y_train = to_categorical(y_train)

x_test = x_test.astype('float32') / 255
y_test = to_categorical(y_test)

x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=10000)

# %%
# model 作成
inputs =  Input(shape=(224,224,3))
x = stem(inputs)
x = learner(x)
outputs = classifier(x, 10)
model = Model(inputs, outputs)

model.compile(
    loss=keras.losses.categorical_crossentropy,
    optimizer="adam",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 64)   36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 64)   0           max_pooling2d[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 64)   36928       add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 64)   36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 64)   0           add[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 64)   36928       add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 64)   36928       conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 64)   0           add_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 128)  73856       add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 128)  147584      conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 128)  147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 128)  147584      conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 128)  0           conv2d_8[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 128)  147584      add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 128)  147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 56, 56, 128)  0           add_3[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 128)  147584      add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 56, 56, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 56, 56, 128)  0           add_4[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 256)  295168      add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 56, 56, 256)  0           conv2d_16[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 56, 56, 256)  590080      add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 56, 56, 256)  0           add_6[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 56, 56, 256)  590080      add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 56, 56, 256)  0           add_7[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 56, 56, 256)  590080      add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 56, 56, 256)  0           add_8[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 56, 56, 256)  590080      add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 56, 56, 256)  0           add_9[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 56, 56, 512)  1180160     add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 56, 56, 512)  2359808     conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 56, 56, 512)  2359808     conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 56, 56, 512)  2359808     conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 56, 56, 512)  0           conv2d_28[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 56, 56, 512)  2359808     add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 56, 56, 512)  2359808     conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 56, 56, 512)  0           add_11[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           add_12[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 21,108,362
# Trainable params: 21,108,362
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen=ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

validation_datagen=ImageDataGenerator()

train_datagen.fit(x_train)
validation_datagen.fit(x_valid)

train_generator=train_datagen.flow(
    x_train,y_train,
    batch_size=100,
    shuffle=True
)

validation_generator=validation_datagen.flow(
    x_valid,y_valid,
    batch_size=100,
    shuffle=True
)

hist=model.fit_generator(train_generator,
                         epochs=100,
                         verbose=1,
                         validation_data=validation_generator)
# Out:
# C:\Users\yudai\anaconda3\envs\py38-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 400/400 [==============================] - 42s 94ms/step - loss: 108.6542 - accuracy: 0.1019 - val_loss: 2.1201 - val_accuracy: 0.1769
# Epoch 2/100
# 400/400 [==============================] - 38s 95ms/step - loss: 2.0168 - accuracy: 0.2175 - val_loss: 1.7784 - val_accuracy: 0.3124
# Epoch 3/100
# 400/400 [==============================] - 37s 92ms/step - loss: 1.7836 - accuracy: 0.3113 - val_loss: 1.6432 - val_accuracy: 0.3641
# Epoch 4/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.6543 - accuracy: 0.3731 - val_loss: 1.5304 - val_accuracy: 0.4338
# Epoch 5/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.5813 - accuracy: 0.4092 - val_loss: 1.4843 - val_accuracy: 0.4560
# Epoch 6/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.5124 - accuracy: 0.4418 - val_loss: 1.4490 - val_accuracy: 0.4729
# Epoch 7/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.4583 - accuracy: 0.4651 - val_loss: 1.3592 - val_accuracy: 0.5027
# Epoch 8/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.3925 - accuracy: 0.4917 - val_loss: 1.2947 - val_accuracy: 0.5267
# Epoch 9/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.3410 - accuracy: 0.5123 - val_loss: 1.2608 - val_accuracy: 0.5381
# Epoch 10/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.2883 - accuracy: 0.5327 - val_loss: 1.2466 - val_accuracy: 0.5543
# Epoch 11/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.2352 - accuracy: 0.5551 - val_loss: 1.2631 - val_accuracy: 0.5392
# Epoch 12/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.2152 - accuracy: 0.5631 - val_loss: 1.2533 - val_accuracy: 0.5551
# Epoch 13/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.1759 - accuracy: 0.5771 - val_loss: 1.1085 - val_accuracy: 0.6021
# Epoch 14/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.1514 - accuracy: 0.5842 - val_loss: 1.2003 - val_accuracy: 0.5727
# Epoch 15/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.1219 - accuracy: 0.5964 - val_loss: 1.0705 - val_accuracy: 0.6133
# Epoch 16/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.1156 - accuracy: 0.6008 - val_loss: 1.0798 - val_accuracy: 0.6173
# Epoch 17/100
# 400/400 [==============================] - 37s 93ms/step - loss: 1.0587 - accuracy: 0.6234 - val_loss: 1.0792 - val_accuracy: 0.6101
# Epoch 18/100
# 400/400 [==============================] - 36s 91ms/step - loss: 1.0501 - accuracy: 0.6249 - val_loss: 1.0221 - val_accuracy: 0.6378
# Epoch 19/100
# 400/400 [==============================] - 36s 91ms/step - loss: 1.0110 - accuracy: 0.6400 - val_loss: 1.0775 - val_accuracy: 0.6253
# Epoch 20/100
# 400/400 [==============================] - 36s 91ms/step - loss: 0.9817 - accuracy: 0.6520 - val_loss: 0.9931 - val_accuracy: 0.6448
# Epoch 21/100
# 400/400 [==============================] - 36s 91ms/step - loss: 0.9717 - accuracy: 0.6546 - val_loss: 1.0621 - val_accuracy: 0.6286
# Epoch 22/100
# 400/400 [==============================] - 36s 91ms/step - loss: 0.9583 - accuracy: 0.6649 - val_loss: 0.9739 - val_accuracy: 0.6574
# Epoch 23/100
# 400/400 [==============================] - 36s 91ms/step - loss: 0.9320 - accuracy: 0.6761 - val_loss: 0.9665 - val_accuracy: 0.6656
# Epoch 24/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.9251 - accuracy: 0.6709 - val_loss: 0.9595 - val_accuracy: 0.6657
# Epoch 25/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.8997 - accuracy: 0.6816 - val_loss: 0.9413 - val_accuracy: 0.6673
# Epoch 26/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.9003 - accuracy: 0.6857 - val_loss: 0.9318 - val_accuracy: 0.6757
# Epoch 27/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.8770 - accuracy: 0.6915 - val_loss: 0.9180 - val_accuracy: 0.6824
# Epoch 28/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.8606 - accuracy: 0.7009 - val_loss: 0.9080 - val_accuracy: 0.6833
# Epoch 29/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.8429 - accuracy: 0.7066 - val_loss: 0.9772 - val_accuracy: 0.6613
# Epoch 30/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.8430 - accuracy: 0.7059 - val_loss: 0.8659 - val_accuracy: 0.6994
# Epoch 31/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.8122 - accuracy: 0.7155 - val_loss: 0.8768 - val_accuracy: 0.6989
# Epoch 32/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.7976 - accuracy: 0.7236 - val_loss: 0.8824 - val_accuracy: 0.6970
# Epoch 33/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.7810 - accuracy: 0.7261 - val_loss: 0.8742 - val_accuracy: 0.6995
# Epoch 34/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.7857 - accuracy: 0.7236 - val_loss: 0.8872 - val_accuracy: 0.6994
# Epoch 35/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.7631 - accuracy: 0.7337 - val_loss: 0.8639 - val_accuracy: 0.7048
# Epoch 36/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.7328 - accuracy: 0.7476 - val_loss: 0.8792 - val_accuracy: 0.6963
# Epoch 37/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.7429 - accuracy: 0.7407 - val_loss: 0.8167 - val_accuracy: 0.7221
# Epoch 38/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.7232 - accuracy: 0.7472 - val_loss: 0.8715 - val_accuracy: 0.7030
# Epoch 39/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.7125 - accuracy: 0.7548 - val_loss: 0.8293 - val_accuracy: 0.7179
# Epoch 40/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.7057 - accuracy: 0.7564 - val_loss: 0.9060 - val_accuracy: 0.6997
# Epoch 41/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.6951 - accuracy: 0.7577 - val_loss: 0.8969 - val_accuracy: 0.7080
# Epoch 42/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.7107 - accuracy: 0.7531 - val_loss: 0.8442 - val_accuracy: 0.7215
# Epoch 43/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.6709 - accuracy: 0.7663 - val_loss: 0.8684 - val_accuracy: 0.7077
# Epoch 44/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.6731 - accuracy: 0.7638 - val_loss: 0.8645 - val_accuracy: 0.7224
# Epoch 45/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.6630 - accuracy: 0.7689 - val_loss: 0.8602 - val_accuracy: 0.7082
# Epoch 46/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.6620 - accuracy: 0.7684 - val_loss: 0.8193 - val_accuracy: 0.7335
# Epoch 47/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.6270 - accuracy: 0.7777 - val_loss: 0.8783 - val_accuracy: 0.7096
# Epoch 48/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.6339 - accuracy: 0.7804 - val_loss: 0.8358 - val_accuracy: 0.7258
# Epoch 49/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.6276 - accuracy: 0.7816 - val_loss: 0.7713 - val_accuracy: 0.7407
# Epoch 50/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.6150 - accuracy: 0.7839 - val_loss: 0.8287 - val_accuracy: 0.7327
# Epoch 51/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.6116 - accuracy: 0.7861 - val_loss: 0.7933 - val_accuracy: 0.7275
# Epoch 52/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.6189 - accuracy: 0.7814 - val_loss: 0.8294 - val_accuracy: 0.7253
# Epoch 53/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.6237 - accuracy: 0.7829 - val_loss: 0.8228 - val_accuracy: 0.7257
# Epoch 54/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.5961 - accuracy: 0.7950 - val_loss: 0.8238 - val_accuracy: 0.7338
# Epoch 55/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.5812 - accuracy: 0.7994 - val_loss: 0.8074 - val_accuracy: 0.7379
# Epoch 56/100
# 400/400 [==============================] - 36s 91ms/step - loss: 0.5918 - accuracy: 0.7965 - val_loss: 0.8241 - val_accuracy: 0.7241
# Epoch 57/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5748 - accuracy: 0.7984 - val_loss: 0.8453 - val_accuracy: 0.7259
# Epoch 58/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5724 - accuracy: 0.8020 - val_loss: 0.7569 - val_accuracy: 0.7453
# Epoch 59/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5611 - accuracy: 0.8090 - val_loss: 0.8055 - val_accuracy: 0.7323
# Epoch 60/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5461 - accuracy: 0.8112 - val_loss: 0.8621 - val_accuracy: 0.7275
# Epoch 61/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5679 - accuracy: 0.8004 - val_loss: 0.8320 - val_accuracy: 0.7289
# Epoch 62/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5471 - accuracy: 0.8072 - val_loss: 0.8195 - val_accuracy: 0.7370
# Epoch 63/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5496 - accuracy: 0.8076 - val_loss: 0.7967 - val_accuracy: 0.7404
# Epoch 64/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5436 - accuracy: 0.8122 - val_loss: 0.8000 - val_accuracy: 0.7407
# Epoch 65/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5331 - accuracy: 0.8122 - val_loss: 0.8354 - val_accuracy: 0.7273
# Epoch 66/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5543 - accuracy: 0.8081 - val_loss: 0.8092 - val_accuracy: 0.7404
# Epoch 67/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5294 - accuracy: 0.8150 - val_loss: 0.8190 - val_accuracy: 0.7380
# Epoch 68/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5201 - accuracy: 0.8191 - val_loss: 0.7900 - val_accuracy: 0.7444
# Epoch 69/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5200 - accuracy: 0.8214 - val_loss: 0.8804 - val_accuracy: 0.7247
# Epoch 70/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5196 - accuracy: 0.8189 - val_loss: 0.8159 - val_accuracy: 0.7406
# Epoch 71/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5084 - accuracy: 0.8207 - val_loss: 0.8192 - val_accuracy: 0.7448
# Epoch 72/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5161 - accuracy: 0.8185 - val_loss: 0.7860 - val_accuracy: 0.7410
# Epoch 73/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.4998 - accuracy: 0.8262 - val_loss: 0.8039 - val_accuracy: 0.7433
# Epoch 74/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.4847 - accuracy: 0.8304 - val_loss: 0.8147 - val_accuracy: 0.7363
# Epoch 75/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.5042 - accuracy: 0.8227 - val_loss: 0.8430 - val_accuracy: 0.7326
# Epoch 76/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.4925 - accuracy: 0.8323 - val_loss: 0.8544 - val_accuracy: 0.7333
# Epoch 77/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.4991 - accuracy: 0.8235 - val_loss: 0.8323 - val_accuracy: 0.7349
# Epoch 78/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.4914 - accuracy: 0.8268 - val_loss: 0.8452 - val_accuracy: 0.7295
# Epoch 79/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.4832 - accuracy: 0.8324 - val_loss: 0.8303 - val_accuracy: 0.7436
# Epoch 80/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.4684 - accuracy: 0.8365 - val_loss: 0.8099 - val_accuracy: 0.7472
# Epoch 81/100
# 400/400 [==============================] - 36s 90ms/step - loss: 0.4799 - accuracy: 0.8329 - val_loss: 0.7726 - val_accuracy: 0.7462
# Epoch 82/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.4580 - accuracy: 0.8398 - val_loss: 0.8214 - val_accuracy: 0.7451
# Epoch 83/100
# 400/400 [==============================] - 38s 96ms/step - loss: 0.4620 - accuracy: 0.8413 - val_loss: 0.8422 - val_accuracy: 0.7368
# Epoch 84/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4565 - accuracy: 0.8413 - val_loss: 0.8911 - val_accuracy: 0.7346
# Epoch 85/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4540 - accuracy: 0.8419 - val_loss: 0.8450 - val_accuracy: 0.7458
# Epoch 86/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.4524 - accuracy: 0.8445 - val_loss: 0.8138 - val_accuracy: 0.7452
# Epoch 87/100
# 400/400 [==============================] - 38s 96ms/step - loss: 0.4527 - accuracy: 0.8415 - val_loss: 0.7635 - val_accuracy: 0.7560
# Epoch 88/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4510 - accuracy: 0.8434 - val_loss: 0.8335 - val_accuracy: 0.7432
# Epoch 89/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4400 - accuracy: 0.8458 - val_loss: 0.8370 - val_accuracy: 0.7459
# Epoch 90/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4551 - accuracy: 0.8421 - val_loss: 0.8281 - val_accuracy: 0.7389
# Epoch 91/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4398 - accuracy: 0.8487 - val_loss: 0.8551 - val_accuracy: 0.7370
# Epoch 92/100
# 400/400 [==============================] - 39s 97ms/step - loss: 0.4363 - accuracy: 0.8469 - val_loss: 0.8331 - val_accuracy: 0.7433
# Epoch 93/100
# 400/400 [==============================] - 39s 97ms/step - loss: 0.4545 - accuracy: 0.8433 - val_loss: 0.8119 - val_accuracy: 0.7498
# Epoch 94/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4298 - accuracy: 0.8479 - val_loss: 0.8497 - val_accuracy: 0.7400
# Epoch 95/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.4409 - accuracy: 0.8496 - val_loss: 0.8374 - val_accuracy: 0.7454
# Epoch 96/100
# 400/400 [==============================] - 42s 104ms/step - loss: 0.4261 - accuracy: 0.8492 - val_loss: 0.8113 - val_accuracy: 0.7490
# Epoch 97/100
# 400/400 [==============================] - 42s 104ms/step - loss: 0.4192 - accuracy: 0.8540 - val_loss: 0.8638 - val_accuracy: 0.7328
# Epoch 98/100
# 400/400 [==============================] - 40s 101ms/step - loss: 0.4223 - accuracy: 0.8530 - val_loss: 0.8876 - val_accuracy: 0.7398
# Epoch 99/100
# 400/400 [==============================] - 38s 96ms/step - loss: 0.4287 - accuracy: 0.8502 - val_loss: 0.8065 - val_accuracy: 0.7514
# Epoch 100/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.4013 - accuracy: 0.8589 - val_loss: 0.8590 - val_accuracy: 0.7523

# %%
def plot_loss(history):
    """エポックごとの損失関数をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    # 損失関数の履歴を取得
    loss_train = history.history["loss"]
    loss_val = history.history["val_loss"]

    # 損失関数をプロット
    epochs=range(1,len(history.history["loss"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs,loss_train,label="Training loss")
    plt.plot(epochs,loss_val,label="Validation loss")
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
def plot_acc(history):
    """エポックごとの正解率をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    acc_train = history.history['accuracy']
    acc_val = history.history['val_accuracy']
    epochs = range(1,len(history.history["accuracy"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs, acc_train, 'g', label='Training accuracy')
    plt.plot(epochs, acc_val, 'b', label='Validation accuracy')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
# 損失関数の描画
plot_loss(hist)

# %%
# 正解率を描画
plot_acc(hist)

# %%
# modelの評価
test_datagen=ImageDataGenerator()
test_datagen.fit(x_test)
test_generator=test_datagen.flow(
    x_test,y_test,
    batch_size=100,
    shuffle=True
)

scores = model.evaluate(test_generator)
# Out:
# 100/100 [==============================] - 3s 28ms/step - loss: 0.8457 - accuracy: 0.7564
