# %% [markdown]
# # VGGNetの概要
# VGGNetはILSVRC-2014で2位の画像認識モデルである. 1位はGoogLeNetであったが実装が複雑であるため省略する. ILSVRC-2014のタスクはILSVRC-2012と同様に画像を分類するタスクである. VGGNetのモデルはVGG-16とVGG-19の2つがあり, 数字は層数を意味している. 次に示すモデルはVGG-16であり, モデルがシンプルなことが特徴である. VGG-19は3層連続している畳み込み層を4層にしたモデルである.
#
#
# - Input : (224,224,3)
#
# - Conv1
#     - Input : (224,224,3)
#     - Filter : (3,3,64)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (224,224,64)
#
# - Conv2
#     - Input : (224,224,64)
#     - Filter : (3,3,64)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (224,224,64)
#
# - Max Pooling
#     - Input : (224,224,64)
#     - Filter : (2,2)
#     - Stride : 2
#     - Output : (112,112,64)
#
# - Conv3
#     - Input : (112,112,64)
#     - Filter : (3,3,128)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (112,112,128)
#
# - Conv4
#     - Input : (112,112,128)
#     - Filter : (3,3,128)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (112,112,128)
#
# - Max Pooling
#     - Input : (112,112,128)
#     - Filter : (2,2)
#     - Stride : 2
#     - Output : (56,56,128)
#
# - Conv5
#     - Input : (56,56,128)
#     - Filter : (3,3,256)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (56,56,256)
#
# - Conv6
#     - Input : (56,56,256)
#     - Filter : (3,3,256)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (56,56,256)
#
# - Conv7
#     - Input : (56,56,256)
#     - Filter : (3,3,256)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (56,56,256)
#
# - Max Pooling
#     - Input : (56,56,256)
#     - Filter : (2,2)
#     - Stride : 2
#     - Output : (28,28,256)
#
# - Conv8
#     - Input : (28,28,256)
#     - Filter : (3,3,512)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (28,28,512)
#
# - Conv9
#     - Input : (28,28,512)
#     - Filter : (3,3,512)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (28,28,512)
#
# - Conv10
#     - Input : (28,28,512)
#     - Filter : (3,3,512)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (28,28,512)
#
# - Max Pooling
#     - Input : (28,28,512)
#     - Filter : (2,2)
#     - Stride : 2
#     - Output : (14,14,512)
#
# - Conv11
#     - Input : (14,14,512)
#     - Filter : (3,3,512)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (14,14,512)
#
# - Conv12
#     - Input : (14,14,512)
#     - Filter : (3,3,512)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (14,14,512)
#
# - Conv13
#     - Input : (14,14,512)
#     - Filter : (3,3,512)
#     - Stride : 1
#     - Activation : ReLU
#     - Output : (14,14,512)
#
# - Max Pooling
#     - Input : (14,14,512)
#     - Filter : (2,2)
#     - Stride : 2
#     - Output : (7,7,512)
#
# - Flatten
#     - Input : (7,7,512)
#     - Output : (25088)
#
# - Dense
#     - Input : (25088)
#     - Activation : ReLU
#     - Output : (4096)
#
# - Dense
#     - Input : (4096)
#     - Activation : ReLU
#     - Output : (4096)
#
# - Dense
#     - Input : (4096)
#     - Activation : Softmax
#     - Output : (1000)

# %% [markdown]
# # VGGNetの実装

# %% [markdown]
# ## VGG-16

# %%
import tensorflow as tf
from IPython.display import SVG
from tensorflow.python.keras.utils.vis_utils import model_to_dot

model = tf.keras.applications.vgg16.VGG16(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 15s 0us/step

# %%
SVG(model_to_dot(model, show_shapes=True, dpi=None).create(prog='dot', format='svg'))

# %%
# モデルを画像として出力
from keras.utils import plot_model
plot_model(model,show_shapes=True,to_file='VGG-16.png')

# %% [markdown]
# ## VGG-19

# %%
model = tf.keras.applications.vgg19.VGG19(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574717952/574710816 [==============================] - 21s 0us/step

# %%
SVG(model_to_dot(model, show_shapes=True, dpi=None).create(prog='dot', format='svg'))

# %%
# モデルを画像として出力
from keras.utils import plot_model
plot_model(model,show_shapes=True,to_file='VGG-19.png')

# %% [markdown]
# ## 転移学習モデル
# kerasには事前学習したVGGNetのモデルがある. このモデルをベースとして学習を行うことを転移学習という. ここでは, VGG-16,VGG-19のそれぞれについてCIFAR-10で転移学習を行い,スコアを比較する.
#
# Reference :
# https://keras.io/ja/applications/#vgg16
# https://keras.io/ja/applications/#vgg19

# %% [markdown]
# ### VGG-16ベースのモデル

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# load CIFAR-10
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.astype('float32') / 255
y_train = np.eye(10)[y_train.astype('int32').flatten()]

x_test = x_test.astype('float32') / 255
y_test = np.eye(10)[y_test.astype('int32').flatten()]

x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=10000)

# %%
import keras
import tensorflow as tf
from IPython.display import SVG
from tensorflow.python.keras.utils.vis_utils import model_to_dot
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D,Input

# base model(VGG-16)を読み込み
# include_top : 出力層側の3つのDenseを含むかどうか
base_model =  tf.keras.applications.vgg16.VGG16(weights='imagenet',include_top=False,input_tensor=Input(shape=(224,224,3)))

# base modelに出力層を追加
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1028,activation="relu")(x)
prediction=Dense(10,activation='softmax')(x)
model=Model(inputs=base_model.input,outputs=prediction)

for layer in base_model.layers[:15]:
    layer.trainable = False
    
model.compile(
    loss=keras.losses.categorical_crossentropy,
    optimizer="adam",
    metrics=["accuracy"]
)

# %%
SVG(model_to_dot(model, show_shapes=True, dpi=None).create(prog='dot', format='svg'))

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen=ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

validation_datagen=ImageDataGenerator()

train_datagen.fit(x_train)
validation_datagen.fit(x_valid)

train_generator=train_datagen.flow(
    x_train,y_train,
    batch_size=100,
    shuffle=True
)

validation_generator=validation_datagen.flow(
    x_valid,y_valid,
    batch_size=100,
    shuffle=True
)

hist=model.fit_generator(train_generator,
                         epochs=50,
                         verbose=1,
                         validation_data=validation_generator)
# Out:
# C:\Users\yudai\anaconda3\envs\py38-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 400/400 [==============================] - 17s 34ms/step - loss: 1.4722 - accuracy: 0.4741 - val_loss: 0.9742 - val_accuracy: 0.6675
# Epoch 2/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.9544 - accuracy: 0.6722 - val_loss: 0.9140 - val_accuracy: 0.6902
# Epoch 3/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.8621 - accuracy: 0.7012 - val_loss: 0.8135 - val_accuracy: 0.7269
# Epoch 4/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.7848 - accuracy: 0.7284 - val_loss: 0.8372 - val_accuracy: 0.7186
# Epoch 5/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.7373 - accuracy: 0.7451 - val_loss: 0.7906 - val_accuracy: 0.7281
# Epoch 6/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.7084 - accuracy: 0.7525 - val_loss: 0.7829 - val_accuracy: 0.7363
# Epoch 7/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.6682 - accuracy: 0.7664 - val_loss: 0.7819 - val_accuracy: 0.7347
# Epoch 8/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.6366 - accuracy: 0.7771 - val_loss: 0.7627 - val_accuracy: 0.7503
# Epoch 9/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.6024 - accuracy: 0.7896 - val_loss: 0.7912 - val_accuracy: 0.7406
# Epoch 10/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.5754 - accuracy: 0.7992 - val_loss: 0.7885 - val_accuracy: 0.7422
# Epoch 11/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.5682 - accuracy: 0.7996 - val_loss: 0.8042 - val_accuracy: 0.7417
# Epoch 12/50
# 400/400 [==============================] - 13s 34ms/step - loss: 0.5415 - accuracy: 0.8083 - val_loss: 0.7707 - val_accuracy: 0.7475
# Epoch 13/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.5166 - accuracy: 0.8177 - val_loss: 0.7680 - val_accuracy: 0.7526
# Epoch 14/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.4825 - accuracy: 0.8307 - val_loss: 0.7984 - val_accuracy: 0.7533
# Epoch 15/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.4722 - accuracy: 0.8334 - val_loss: 0.8561 - val_accuracy: 0.7459
# Epoch 16/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.4474 - accuracy: 0.8428 - val_loss: 0.8258 - val_accuracy: 0.7508
# Epoch 17/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.4418 - accuracy: 0.8458 - val_loss: 0.8674 - val_accuracy: 0.7469
# Epoch 18/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.4274 - accuracy: 0.8486 - val_loss: 0.8383 - val_accuracy: 0.7459
# Epoch 19/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.3961 - accuracy: 0.8582 - val_loss: 0.8506 - val_accuracy: 0.7501
# Epoch 20/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.3716 - accuracy: 0.8705 - val_loss: 0.8617 - val_accuracy: 0.7538
# Epoch 21/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.3698 - accuracy: 0.8678 - val_loss: 0.9406 - val_accuracy: 0.7502
# Epoch 22/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.3531 - accuracy: 0.8768 - val_loss: 0.9166 - val_accuracy: 0.7535
# Epoch 23/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.3351 - accuracy: 0.8828 - val_loss: 0.9191 - val_accuracy: 0.7516
# Epoch 24/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.3247 - accuracy: 0.8840 - val_loss: 0.9895 - val_accuracy: 0.7395
# Epoch 25/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.3020 - accuracy: 0.8949 - val_loss: 0.9379 - val_accuracy: 0.7481
# Epoch 26/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.2890 - accuracy: 0.8977 - val_loss: 0.8888 - val_accuracy: 0.7585
# Epoch 27/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.2979 - accuracy: 0.8956 - val_loss: 0.9327 - val_accuracy: 0.7508
# Epoch 28/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.2749 - accuracy: 0.9040 - val_loss: 0.9906 - val_accuracy: 0.7546
# Epoch 29/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.2746 - accuracy: 0.9043 - val_loss: 1.0075 - val_accuracy: 0.7497
# Epoch 30/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.2507 - accuracy: 0.9129 - val_loss: 0.9766 - val_accuracy: 0.7528
# Epoch 31/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.2571 - accuracy: 0.9083 - val_loss: 1.0404 - val_accuracy: 0.7513
# Epoch 32/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.2398 - accuracy: 0.9171 - val_loss: 1.0634 - val_accuracy: 0.7589
# Epoch 33/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.2339 - accuracy: 0.9175 - val_loss: 1.0653 - val_accuracy: 0.7506
# Epoch 34/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.2292 - accuracy: 0.9185 - val_loss: 1.0809 - val_accuracy: 0.7552
# Epoch 35/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.2094 - accuracy: 0.9283 - val_loss: 1.0540 - val_accuracy: 0.7519
# Epoch 36/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.2211 - accuracy: 0.9246 - val_loss: 1.0813 - val_accuracy: 0.7579
# Epoch 37/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1992 - accuracy: 0.9312 - val_loss: 1.0774 - val_accuracy: 0.7492
# Epoch 38/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1976 - accuracy: 0.9335 - val_loss: 1.1443 - val_accuracy: 0.7535
# Epoch 39/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1963 - accuracy: 0.9319 - val_loss: 1.1302 - val_accuracy: 0.7485
# Epoch 40/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1953 - accuracy: 0.9341 - val_loss: 1.1963 - val_accuracy: 0.7432
# Epoch 41/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1849 - accuracy: 0.9395 - val_loss: 1.1609 - val_accuracy: 0.7599
# Epoch 42/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1729 - accuracy: 0.9404 - val_loss: 1.1574 - val_accuracy: 0.7560
# Epoch 43/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1789 - accuracy: 0.9412 - val_loss: 1.1284 - val_accuracy: 0.7511
# Epoch 44/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1688 - accuracy: 0.9432 - val_loss: 1.2042 - val_accuracy: 0.7480
# Epoch 45/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1628 - accuracy: 0.9440 - val_loss: 1.2292 - val_accuracy: 0.7494
# Epoch 46/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1744 - accuracy: 0.9398 - val_loss: 1.2387 - val_accuracy: 0.7556
# Epoch 47/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1519 - accuracy: 0.9504 - val_loss: 1.2793 - val_accuracy: 0.7472
# Epoch 48/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1665 - accuracy: 0.9453 - val_loss: 1.2362 - val_accuracy: 0.7490
# Epoch 49/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1467 - accuracy: 0.9516 - val_loss: 1.3104 - val_accuracy: 0.7468
# Epoch 50/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.1392 - accuracy: 0.9517 - val_loss: 1.3163 - val_accuracy: 0.7441

# %%
def plot_loss(history):
    """エポックごとの損失関数をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    # 損失関数の履歴を取得
    loss_train = history.history["loss"]
    loss_val = history.history["val_loss"]

    # 損失関数をプロット
    epochs=range(1,len(history.history["loss"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs,loss_train,label="Training loss")
    plt.plot(epochs,loss_val,label="Validation loss")
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
def plot_acc(history):
    """エポックごとの正解率をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    acc_train = history.history['accuracy']
    acc_val = history.history['val_accuracy']
    epochs = range(1,len(history.history["accuracy"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs, acc_train, 'g', label='Training accuracy')
    plt.plot(epochs, acc_val, 'b', label='Validation accuracy')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
# 損失関数の描画
plot_loss(hist)

# %%
# 正解率を描画
plot_acc(hist)

# %%
# modelの評価
test_datagen=ImageDataGenerator()
test_datagen.fit(x_test)
test_generator=test_datagen.flow(
    x_test,y_test,
    batch_size=100,
    shuffle=True
)

scores = model.evaluate(test_generator)
# Out:
# 100/100 [==============================] - 1s 13ms/step - loss: 1.3789 - accuracy: 0.7327

# %% [markdown]
# ### VGG-19ベースのモデル

# %%
import keras
import tensorflow as tf
from IPython.display import SVG
from tensorflow.python.keras.utils.vis_utils import model_to_dot
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D,Input

# base model(VGG-16)を読み込み
# include_top : 出力層側の3つのDenseを含むかどうか
base_model =  tf.keras.applications.vgg19.VGG19(weights='imagenet',include_top=False,input_tensor=Input(shape=(224,224,3)))

# base modelに出力層を追加
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1028,activation="relu")(x)
prediction=Dense(10,activation='softmax')(x)
model=Model(inputs=base_model.input,outputs=prediction)

for layer in base_model.layers[:15]:
    layer.trainable = False
    
model.compile(
    loss=keras.losses.categorical_crossentropy,
    optimizer="adam",
    metrics=["accuracy"]
)

# %%
SVG(model_to_dot(model, show_shapes=True, dpi=None).create(prog='dot', format='svg'))

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen=ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

validation_datagen=ImageDataGenerator()

train_datagen.fit(x_train)
validation_datagen.fit(x_valid)

train_generator=train_datagen.flow(
    x_train,y_train,
    batch_size=100,
    shuffle=True
)

validation_generator=validation_datagen.flow(
    x_valid,y_valid,
    batch_size=100,
    shuffle=True
)

hist=model.fit_generator(train_generator,
                         epochs=50,
                         verbose=1,
                         validation_data=validation_generator)
# Out:
# C:\Users\yudai\anaconda3\envs\py38-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 400/400 [==============================] - 24s 38ms/step - loss: 2.0959 - accuracy: 0.1884 - val_loss: 1.1569 - val_accuracy: 0.5852
# Epoch 2/50
# 400/400 [==============================] - 14s 35ms/step - loss: 1.1807 - accuracy: 0.5789 - val_loss: 1.0347 - val_accuracy: 0.6484
# Epoch 3/50
# 400/400 [==============================] - 14s 35ms/step - loss: 1.0000 - accuracy: 0.6640 - val_loss: 0.9503 - val_accuracy: 0.6754
# Epoch 4/50
# 400/400 [==============================] - 14s 35ms/step - loss: 0.9108 - accuracy: 0.6923 - val_loss: 0.8309 - val_accuracy: 0.7170
# Epoch 5/50
# 400/400 [==============================] - 14s 34ms/step - loss: 0.8604 - accuracy: 0.7075 - val_loss: 0.8177 - val_accuracy: 0.7237
# Epoch 6/50
# 400/400 [==============================] - 14s 34ms/step - loss: 0.8184 - accuracy: 0.7223 - val_loss: 0.8024 - val_accuracy: 0.7231
# Epoch 7/50
# 400/400 [==============================] - 14s 34ms/step - loss: 0.7853 - accuracy: 0.7327 - val_loss: 0.7820 - val_accuracy: 0.7333
# Epoch 8/50
# 400/400 [==============================] - 14s 34ms/step - loss: 0.7605 - accuracy: 0.7390 - val_loss: 0.7888 - val_accuracy: 0.7364
# Epoch 9/50
# 400/400 [==============================] - 14s 35ms/step - loss: 0.7346 - accuracy: 0.7523 - val_loss: 0.7547 - val_accuracy: 0.7438
# Epoch 10/50
# 400/400 [==============================] - 14s 35ms/step - loss: 0.7179 - accuracy: 0.7531 - val_loss: 0.7559 - val_accuracy: 0.7484
# Epoch 11/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.7010 - accuracy: 0.7653 - val_loss: 0.7600 - val_accuracy: 0.7501
# Epoch 12/50
# 400/400 [==============================] - 13s 34ms/step - loss: 0.6898 - accuracy: 0.7619 - val_loss: 0.7563 - val_accuracy: 0.7430
# Epoch 13/50
# 400/400 [==============================] - 14s 35ms/step - loss: 0.6768 - accuracy: 0.7689 - val_loss: 0.7529 - val_accuracy: 0.7488
# Epoch 14/50
# 400/400 [==============================] - 15s 36ms/step - loss: 0.6428 - accuracy: 0.7787 - val_loss: 0.7334 - val_accuracy: 0.7521
# Epoch 15/50
# 400/400 [==============================] - 15s 38ms/step - loss: 0.6403 - accuracy: 0.7846 - val_loss: 0.7290 - val_accuracy: 0.7609
# Epoch 16/50
# 400/400 [==============================] - 15s 36ms/step - loss: 0.6109 - accuracy: 0.7930 - val_loss: 0.7087 - val_accuracy: 0.7675
# Epoch 17/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.6030 - accuracy: 0.7911 - val_loss: 0.7291 - val_accuracy: 0.7617
# Epoch 18/50
# 400/400 [==============================] - 15s 37ms/step - loss: 0.6075 - accuracy: 0.7884 - val_loss: 0.7343 - val_accuracy: 0.7638
# Epoch 19/50
# 400/400 [==============================] - 15s 36ms/step - loss: 0.5875 - accuracy: 0.7962 - val_loss: 0.6948 - val_accuracy: 0.7681
# Epoch 20/50
# 400/400 [==============================] - 14s 35ms/step - loss: 0.5714 - accuracy: 0.8045 - val_loss: 0.7808 - val_accuracy: 0.7449
# Epoch 21/50
# 400/400 [==============================] - 14s 35ms/step - loss: 0.5675 - accuracy: 0.8021 - val_loss: 0.7114 - val_accuracy: 0.7677
# Epoch 22/50
# 400/400 [==============================] - 14s 35ms/step - loss: 0.5538 - accuracy: 0.8067 - val_loss: 0.7090 - val_accuracy: 0.7672
# Epoch 23/50
# 400/400 [==============================] - 14s 35ms/step - loss: 0.5579 - accuracy: 0.8094 - val_loss: 0.7109 - val_accuracy: 0.7635
# Epoch 24/50
# 400/400 [==============================] - 14s 34ms/step - loss: 0.5341 - accuracy: 0.8169 - val_loss: 0.7550 - val_accuracy: 0.7672
# Epoch 25/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.5214 - accuracy: 0.8181 - val_loss: 0.7665 - val_accuracy: 0.7656
# Epoch 26/50
# 400/400 [==============================] - 13s 33ms/step - loss: 0.5146 - accuracy: 0.8255 - val_loss: 0.7420 - val_accuracy: 0.7696
# Epoch 27/50
# 400/400 [==============================] - 14s 34ms/step - loss: 0.5006 - accuracy: 0.8259 - val_loss: 0.7372 - val_accuracy: 0.7690
# Epoch 28/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.5077 - accuracy: 0.8255 - val_loss: 0.7196 - val_accuracy: 0.7739
# Epoch 29/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.4831 - accuracy: 0.8327 - val_loss: 0.7415 - val_accuracy: 0.7724
# Epoch 30/50
# 400/400 [==============================] - 14s 35ms/step - loss: 0.4733 - accuracy: 0.8347 - val_loss: 0.7526 - val_accuracy: 0.7650
# Epoch 31/50
# 400/400 [==============================] - 14s 35ms/step - loss: 0.4684 - accuracy: 0.8405 - val_loss: 0.7651 - val_accuracy: 0.7671
# Epoch 32/50
# 400/400 [==============================] - 15s 37ms/step - loss: 0.4591 - accuracy: 0.8417 - val_loss: 0.7376 - val_accuracy: 0.7721
# Epoch 33/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.4546 - accuracy: 0.8429 - val_loss: 0.7570 - val_accuracy: 0.7710
# Epoch 34/50
# 400/400 [==============================] - 15s 36ms/step - loss: 0.4568 - accuracy: 0.8423 - val_loss: 0.7566 - val_accuracy: 0.7734
# Epoch 35/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.4367 - accuracy: 0.8469 - val_loss: 0.8024 - val_accuracy: 0.7607
# Epoch 36/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.4474 - accuracy: 0.8468 - val_loss: 0.7895 - val_accuracy: 0.7706
# Epoch 37/50
# 400/400 [==============================] - 15s 37ms/step - loss: 0.4202 - accuracy: 0.8572 - val_loss: 0.7913 - val_accuracy: 0.7696
# Epoch 38/50
# 400/400 [==============================] - 15s 36ms/step - loss: 0.4261 - accuracy: 0.8507 - val_loss: 0.7586 - val_accuracy: 0.7735
# Epoch 39/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.4055 - accuracy: 0.8598 - val_loss: 0.7454 - val_accuracy: 0.7667
# Epoch 40/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.4099 - accuracy: 0.8574 - val_loss: 0.8262 - val_accuracy: 0.7614
# Epoch 41/50
# 400/400 [==============================] - 15s 36ms/step - loss: 0.3953 - accuracy: 0.8626 - val_loss: 0.7953 - val_accuracy: 0.7671
# Epoch 42/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.4422 - accuracy: 0.8483 - val_loss: 0.7697 - val_accuracy: 0.7747
# Epoch 43/50
# 400/400 [==============================] - 15s 36ms/step - loss: 0.3852 - accuracy: 0.8638 - val_loss: 0.7886 - val_accuracy: 0.7704
# Epoch 44/50
# 400/400 [==============================] - 15s 37ms/step - loss: 0.3852 - accuracy: 0.8684 - val_loss: 0.8053 - val_accuracy: 0.7785
# Epoch 45/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.3700 - accuracy: 0.8701 - val_loss: 0.7724 - val_accuracy: 0.7776
# Epoch 46/50
# 400/400 [==============================] - 15s 36ms/step - loss: 0.3559 - accuracy: 0.8760 - val_loss: 0.8039 - val_accuracy: 0.7613
# Epoch 47/50
# 400/400 [==============================] - 15s 36ms/step - loss: 0.3592 - accuracy: 0.8770 - val_loss: 0.7571 - val_accuracy: 0.7775
# Epoch 48/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.3514 - accuracy: 0.8800 - val_loss: 0.7892 - val_accuracy: 0.7697
# Epoch 49/50
# 400/400 [==============================] - 15s 36ms/step - loss: 0.3532 - accuracy: 0.8772 - val_loss: 0.8479 - val_accuracy: 0.7641
# Epoch 50/50
# 400/400 [==============================] - 14s 36ms/step - loss: 0.3536 - accuracy: 0.8767 - val_loss: 0.8586 - val_accuracy: 0.7661

# %%
# 損失関数の描画
plot_loss(hist)

# %%
# 正解率を描画
plot_acc(hist)

# %%
# modelの評価
test_datagen=ImageDataGenerator()
test_datagen.fit(x_test)
test_generator=test_datagen.flow(
    x_test,y_test,
    batch_size=100,
    shuffle=True
)

scores = model.evaluate(test_generator)
# Out:
# 100/100 [==============================] - 2s 15ms/step - loss: 0.8704 - accuracy: 0.7634
