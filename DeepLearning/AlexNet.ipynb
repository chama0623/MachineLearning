# %% [markdown]
# # AlexNetの概要
# AlexNetはILSVRC-2012の画像コンペティションで優勝したCNNである. このCNNのタスクは256x256ピクセルのカラー画像を1000クラスに分類することである. クラスにはヒョウ,ユキヒョウ,チーター,ジャガーといった人間でも判別が難しいものを含まれている. データは訓練セットが1.2M個の画像, 検証セットが50k個の画像, テストセットが150k個の画像で構成されている. AlexNetのモデルは次のようになっている(画像は論文から引用).
#
# ![AlexNet](./AlexNet-Architecture.png)
#
# - Input (224,224,3)
#
# - Layer1
#     - Input (224,224,3)
#     - Filter : (11,11,96)
#     - Stride : 4
#     - Pagging 0
#     - Local Response Normalization
#     - Output (55,55,48)x2
#
# - Max Pooling
#     - Filter : (3,3)
#     - Stride : 2
#     - Output : (27,27,48)x2
#
# - Layer2
#     - Input : (27,27,48)x2
#     - Filter : (5,5)
#     - Stride : 1
#
# - Max Pooling
#     - Filter : (3,3)
#     - Stride : 2
#     - Output : (13,13,128)x2
#
# - Layer3
#     - Input : (13,13,128)x2
#     - Filter : (3,3)
#     - Stride : 1
#     - 2並列の結果を混ぜる
#     - Output : (13,13,192)x2
#
# - Layer4
#     - Input : (13,13,192)x2
#     - Filter : (3,3)
#     - Stride : 1
#     - Output : (13,13,192)x2
#
# - Layer5
#     - Input : (13,13,192)x2
#     - Filter : (3,3)
#     - Stride : 1
#     - Output : (13,13,128)x2
#
# - Max Pooling
#     - Filter : (3,3)
#     - Stride : 2
#     - Output : (6,6,128)x2
#
# - Flatten
#     - Input : (6,6,128)x2
#     - Output : (4608)x2
#
# - Dense
#     - Input : (4608)x2
#     - Output : (2048)x2
#
# - Dropout 0.5
#
# - Dense
#     - Input : (2048)x2
#     - Output : (2048)x2
#
# - Dropout 0.5
#
# - Dense
#     - Input : (2048)x2
#     - Output : (1000)

# %% [markdown]
# # AlexNetの実装
# データ容量の都合で実際のAlexNetを再現することは困難だから, Kerasで実際のAlexNetのモデルの作成と, これを簡略化したモデルで実装を行う. 簡略化したモデルではデータとしてCIFAR-10を用いる.

# %% [markdown]
# ## AlexNetのモデル

# %%
import keras
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Input, Activation, add, Add, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential, Model
from IPython.display import SVG
from tensorflow.python.keras.utils.vis_utils import model_to_dot

model = Sequential()
# Layer1
# (224,224,3) -> (27,27,96)
model.add(Conv2D(96, kernel_size=(11, 11), activation="relu",strides=(4,4),padding="same",input_shape=(224, 224, 3)))
model.add(MaxPooling2D((3, 3), strides=(2, 2))) 
model.add(BatchNormalization())
# Layer2
# (27,27,96) -> (13,13,256)
model.add(Conv2D(256, kernel_size=(5, 5), activation="relu",strides=(1,1),padding="same"))
model.add(MaxPooling2D((3, 3), strides=(2, 2))) 
model.add(BatchNormalization())
# Layer3
# (13,13,256) -> (13,13,384)
model.add(Conv2D(384, kernel_size=(3, 3), activation="relu",strides=(1,1),padding="same"))
# Layer4
# (13,13,384) -> (13,13,384)
model.add(Conv2D(384, kernel_size=(3, 3), activation="relu",strides=(1,1),padding="same"))
# Layer5
# (13,13,384) -> (13,13,256)
model.add(Conv2D(256, kernel_size=(3, 3), activation="relu",strides=(1,1),padding="same"))
model.add(MaxPooling2D((3, 3), strides=(2, 2)))
model.add(BatchNormalization())
# Flatten
model.add(Flatten())
# Dense
model.add(Dense(4096,activation="relu"))
# Dropout
model.add(Dropout(0.5))
# Dense
model.add(Dense(4096,activation="relu"))
# Dropout
model.add(Dropout(0.5))
# Dense
model.add(Dense(1000,activation="softmax"))

# %%
SVG(model_to_dot(model, show_shapes=True, dpi=None).create(prog='dot', format='svg'))

# %%
# モデルを画像として出力
from keras.utils import plot_model
plot_model(model,show_shapes=True,to_file='Alexnet.png')

# %% [markdown]
# ## CIFAR-10による検証
# AlexNetを簡略化したモデルでCIFAR-10の分類を行う. 用いるモデルは次の通りである. AlexNetとの違いは<span style="color:red">赤文字</span>で記載している.
#
# - <span style="color:red">Input (32,32,3)</span>
#
# - Layer1
#     - <span style="color:red">Input (32,32,3)</span>
#     - <span style="color:red">Filter : (3,3,96)</span>
#     - Stride : 1
#     - <span style="color:red">Padding 1</span>
#     - Local Response Normalization
#     - <span style="color:red">Output (32,32,48)x2</span>
#
# - Max Pooling
#     - <span style="color:red">Filter : (2,2)</span>
#     - Stride : 2
#     - <span style="color:red">Output : (16,16,48)x2</span>
#
# - Layer2
#     - <span style="color:red">Input : (16,16,48)x2</span>
#     - Filter : (5,5)
#     - Stride : 1
#
# - Max Pooling
#     - <span style="color:red">Filter : (2,2)</span>
#     - Stride : 2
#     - <span style="color:red">Output : (8,8,128)x2</span>
#
# - Layer3
#     - <span style="color:red">Input : (8,8,128)x2</span>
#     - Filter : (3,3)
#     - Stride : 1
#     - 2並列の結果を混ぜる
#     - <span style="color:red">Output : (8,8,192)x2</span>
#
# - Layer4
#     - <span style="color:red">Input : (8,8,192)x2</span>
#     - Filter : (3,3)
#     - Stride : 1
#     - <span style="color:red">Output : (8,8,192)x2</span>
#
# - Layer5
#     - <span style="color:red">Input : (8,8,192)x2</span>
#     - Filter : (3,3)
#     - Stride : 1
#     - <span style="color:red">Output : (8,8,128)x2</span>
#
# - Max Pooling
#     - <span style="color:red">Filter : (2,2)</span>
#     - Stride : 2
#     - <span style="color:red">Output : (4,4,128)x2</span>
#
# - Flatten
#     - <span style="color:red">Input : (4,4,128)x2</span>
#     - <span style="color:red">Output : (2048)x2</span>
#
# - Dense
#     - <span style="color:red">Input : (2048)x2</span>
#     - <span style="color:red">Output : (1024)x2</span>
#
# - Dropout 0.5
#
# - Dense
#     - <span style="color:red">Input : (1024)x2</span>
#     - <span style="color:red">Output : (1024)x2</span>
#
# - Dropout 0.5
#
# - Dense
#     - <span style="color:red">Input : (1024)x2</span>
#     - <span style="color:red">Output : (10)</span>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# load CIFAR-10
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train.astype('float32') / 255
y_train = np.eye(10)[y_train.astype('int32').flatten()]

x_test = x_test.astype('float32') / 255
y_test = np.eye(10)[y_test.astype('int32').flatten()]

x_train, x_valid, y_train, y_valid = train_test_split(
    x_train, y_train, test_size=10000)

# %%
import keras
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Input, Activation, add, Add, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential, Model
from IPython.display import SVG
from tensorflow.python.keras.utils.vis_utils import model_to_dot

model = Sequential()
# Layer1
# (32,32,3) -> (27,27,96)
model.add(Conv2D(96, kernel_size=(3, 3), activation="relu",strides=(1,1),padding="same",input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2), strides=(2, 2))) 
model.add(BatchNormalization())
# Layer2
# (32,32,96) -> (16,16,256)
model.add(Conv2D(256, kernel_size=(5, 5), activation="relu",strides=(1,1),padding="same"))
model.add(MaxPooling2D((2, 2), strides=(2, 2))) 
model.add(BatchNormalization())
# Layer3
# (16,16,256) -> (8,8,384)
model.add(Conv2D(384, kernel_size=(3, 3), activation="relu",strides=(1,1),padding="same"))
# Layer4
# (8,8,384) -> (8,8,384)
model.add(Conv2D(384, kernel_size=(3, 3), activation="relu",strides=(1,1),padding="same"))
# Layer5
# (8,8,384) -> (8,8,256)
model.add(Conv2D(256, kernel_size=(3, 3), activation="relu",strides=(1,1),padding="same"))
model.add(MaxPooling2D((2, 2), strides=(2, 2)))
model.add(BatchNormalization())
# Flatten
model.add(Flatten())
# Dense
model.add(Dense(2048,activation="relu"))
# Dropout
model.add(Dropout(0.5))
# Dense
model.add(Dense(2048,activation="relu"))
# Dropout
model.add(Dropout(0.5))
# Dense
model.add(Dense(10,activation="softmax"))

model.compile(
    loss=keras.losses.categorical_crossentropy,
    optimizer="adam",
    metrics=["accuracy"]
)

# %%
SVG(model_to_dot(model, show_shapes=True, dpi=None).create(prog='dot', format='svg'))

# %%
history = model.fit(x_train,y_train,batch_size=100,steps_per_epoch=x_train.shape[0] // 100, epochs=100, validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/100
# 400/400 [==============================] - 15s 31ms/step - loss: 2.1039 - accuracy: 0.3191 - val_loss: 5.9261 - val_accuracy: 0.1036
# Epoch 2/100
# 400/400 [==============================] - 12s 29ms/step - loss: 1.2612 - accuracy: 0.5502 - val_loss: 1.1254 - val_accuracy: 0.6031
# Epoch 3/100
# 400/400 [==============================] - 12s 29ms/step - loss: 1.0118 - accuracy: 0.6473 - val_loss: 1.0465 - val_accuracy: 0.6352
# Epoch 4/100
# 400/400 [==============================] - 12s 29ms/step - loss: 0.8605 - accuracy: 0.7036 - val_loss: 0.8996 - val_accuracy: 0.6930
# Epoch 5/100
# 400/400 [==============================] - 12s 29ms/step - loss: 0.7451 - accuracy: 0.7452 - val_loss: 1.0328 - val_accuracy: 0.6505
# Epoch 6/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.6640 - accuracy: 0.7731 - val_loss: 0.8252 - val_accuracy: 0.7138
# Epoch 7/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.5788 - accuracy: 0.8046 - val_loss: 0.8992 - val_accuracy: 0.7050
# Epoch 8/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.4913 - accuracy: 0.8332 - val_loss: 0.8310 - val_accuracy: 0.7245
# Epoch 9/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.4130 - accuracy: 0.8576 - val_loss: 0.8366 - val_accuracy: 0.7337
# Epoch 10/100
# 400/400 [==============================] - 25s 62ms/step - loss: 0.3593 - accuracy: 0.8782 - val_loss: 0.9154 - val_accuracy: 0.6966
# Epoch 11/100
# 400/400 [==============================] - 21s 52ms/step - loss: 0.3194 - accuracy: 0.8927 - val_loss: 0.9177 - val_accuracy: 0.7285
# Epoch 12/100
# 400/400 [==============================] - 22s 55ms/step - loss: 0.2801 - accuracy: 0.9071 - val_loss: 0.8783 - val_accuracy: 0.7408
# Epoch 13/100
# 400/400 [==============================] - 23s 57ms/step - loss: 0.2300 - accuracy: 0.9235 - val_loss: 0.8786 - val_accuracy: 0.7736
# Epoch 14/100
# 400/400 [==============================] - 22s 56ms/step - loss: 0.2192 - accuracy: 0.9283 - val_loss: 0.8798 - val_accuracy: 0.7364
# Epoch 15/100
# 400/400 [==============================] - 25s 64ms/step - loss: 0.1830 - accuracy: 0.9404 - val_loss: 0.9202 - val_accuracy: 0.7325
# Epoch 16/100
# 400/400 [==============================] - 27s 67ms/step - loss: 0.1929 - accuracy: 0.9379 - val_loss: 0.9400 - val_accuracy: 0.7546
# Epoch 17/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.1575 - accuracy: 0.9493 - val_loss: 0.8339 - val_accuracy: 0.7817
# Epoch 18/100
# 400/400 [==============================] - 15s 38ms/step - loss: 0.1442 - accuracy: 0.9540 - val_loss: 0.9407 - val_accuracy: 0.7535
# Epoch 19/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.1506 - accuracy: 0.9537 - val_loss: 0.9122 - val_accuracy: 0.7868
# Epoch 20/100
# 400/400 [==============================] - 32s 79ms/step - loss: 0.1281 - accuracy: 0.9628 - val_loss: 1.0145 - val_accuracy: 0.7367
# Epoch 21/100
# 400/400 [==============================] - 20s 50ms/step - loss: 0.1100 - accuracy: 0.9660 - val_loss: 0.8934 - val_accuracy: 0.7900
# Epoch 22/100
# 400/400 [==============================] - 27s 68ms/step - loss: 0.1220 - accuracy: 0.9630 - val_loss: 1.1271 - val_accuracy: 0.7694
# Epoch 23/100
# 400/400 [==============================] - 31s 78ms/step - loss: 0.1039 - accuracy: 0.9688 - val_loss: 1.1797 - val_accuracy: 0.7259
# Epoch 24/100
# 400/400 [==============================] - 25s 63ms/step - loss: 0.1008 - accuracy: 0.9702 - val_loss: 1.0152 - val_accuracy: 0.7842
# Epoch 25/100
# 400/400 [==============================] - 32s 81ms/step - loss: 0.1133 - accuracy: 0.9680 - val_loss: 1.1966 - val_accuracy: 0.7614
# Epoch 26/100
# 400/400 [==============================] - 20s 50ms/step - loss: 0.0955 - accuracy: 0.9716 - val_loss: 0.8904 - val_accuracy: 0.7939
# Epoch 27/100
# 400/400 [==============================] - 18s 44ms/step - loss: 0.0973 - accuracy: 0.9720 - val_loss: 1.0634 - val_accuracy: 0.7824
# Epoch 28/100
# 400/400 [==============================] - 24s 59ms/step - loss: 0.0850 - accuracy: 0.9761 - val_loss: 0.9846 - val_accuracy: 0.7791
# Epoch 29/100
# 400/400 [==============================] - 24s 60ms/step - loss: 0.0836 - accuracy: 0.9765 - val_loss: 1.0234 - val_accuracy: 0.7845
# Epoch 30/100
# 400/400 [==============================] - 15s 37ms/step - loss: 0.0848 - accuracy: 0.9758 - val_loss: 0.9979 - val_accuracy: 0.7925
# Epoch 31/100
# 400/400 [==============================] - 19s 47ms/step - loss: 0.0865 - accuracy: 0.9747 - val_loss: 1.0412 - val_accuracy: 0.7901
# Epoch 32/100
# 400/400 [==============================] - 13s 34ms/step - loss: 0.0733 - accuracy: 0.9788 - val_loss: 1.0514 - val_accuracy: 0.7833
# Epoch 33/100
# 400/400 [==============================] - 13s 34ms/step - loss: 0.0760 - accuracy: 0.9780 - val_loss: 1.3139 - val_accuracy: 0.7630
# Epoch 34/100
# 400/400 [==============================] - 13s 34ms/step - loss: 0.0764 - accuracy: 0.9795 - val_loss: 0.9942 - val_accuracy: 0.7987
# Epoch 35/100
# 400/400 [==============================] - 14s 34ms/step - loss: 0.0670 - accuracy: 0.9818 - val_loss: 1.1628 - val_accuracy: 0.7920
# Epoch 36/100
# 400/400 [==============================] - 13s 34ms/step - loss: 0.0597 - accuracy: 0.9826 - val_loss: 1.2661 - val_accuracy: 0.7681
# Epoch 37/100
# 400/400 [==============================] - 14s 35ms/step - loss: 0.0891 - accuracy: 0.9757 - val_loss: 1.1532 - val_accuracy: 0.7962
# Epoch 38/100
# 400/400 [==============================] - 13s 34ms/step - loss: 0.0574 - accuracy: 0.9841 - val_loss: 1.2396 - val_accuracy: 0.7891
# Epoch 39/100
# 400/400 [==============================] - 18s 45ms/step - loss: 0.0709 - accuracy: 0.9807 - val_loss: 1.0465 - val_accuracy: 0.7850
# Epoch 40/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0640 - accuracy: 0.9834 - val_loss: 1.1209 - val_accuracy: 0.7959
# Epoch 41/100
# 400/400 [==============================] - 19s 47ms/step - loss: 0.0821 - accuracy: 0.9792 - val_loss: 1.0933 - val_accuracy: 0.7437
# Epoch 42/100
# 400/400 [==============================] - 17s 43ms/step - loss: 0.0892 - accuracy: 0.9751 - val_loss: 1.0451 - val_accuracy: 0.7940
# Epoch 43/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0529 - accuracy: 0.9852 - val_loss: 2.8393 - val_accuracy: 0.7689
# Epoch 44/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0649 - accuracy: 0.9838 - val_loss: 1.0874 - val_accuracy: 0.7798
# Epoch 45/100
# 400/400 [==============================] - 17s 41ms/step - loss: 0.0458 - accuracy: 0.9876 - val_loss: 1.0913 - val_accuracy: 0.8000
# Epoch 46/100
# 400/400 [==============================] - 17s 43ms/step - loss: 0.0445 - accuracy: 0.9872 - val_loss: 1.1173 - val_accuracy: 0.7943
# Epoch 47/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0452 - accuracy: 0.9873 - val_loss: 1.3102 - val_accuracy: 0.7344
# Epoch 48/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0603 - accuracy: 0.9847 - val_loss: 1.0929 - val_accuracy: 0.7906
# Epoch 49/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0582 - accuracy: 0.9848 - val_loss: 1.0697 - val_accuracy: 0.7857
# Epoch 50/100
# 400/400 [==============================] - 17s 41ms/step - loss: 0.0623 - accuracy: 0.9850 - val_loss: 1.3292 - val_accuracy: 0.7898
# Epoch 51/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0611 - accuracy: 0.9852 - val_loss: 1.3079 - val_accuracy: 0.7804
# Epoch 52/100
# 400/400 [==============================] - 18s 46ms/step - loss: 0.0415 - accuracy: 0.9893 - val_loss: 1.1265 - val_accuracy: 0.8071
# Epoch 53/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0482 - accuracy: 0.9875 - val_loss: 1.3572 - val_accuracy: 0.7909
# Epoch 54/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0650 - accuracy: 0.9840 - val_loss: 1.2539 - val_accuracy: 0.7867
# Epoch 55/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0455 - accuracy: 0.9880 - val_loss: 1.8592 - val_accuracy: 0.6902
# Epoch 56/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0480 - accuracy: 0.9875 - val_loss: 1.2833 - val_accuracy: 0.7554
# Epoch 57/100
# 400/400 [==============================] - 18s 44ms/step - loss: 0.0464 - accuracy: 0.9873 - val_loss: 1.1353 - val_accuracy: 0.8009
# Epoch 58/100
# 400/400 [==============================] - 18s 44ms/step - loss: 0.0519 - accuracy: 0.9869 - val_loss: 1.0718 - val_accuracy: 0.7876
# Epoch 59/100
# 400/400 [==============================] - 18s 45ms/step - loss: 0.0533 - accuracy: 0.9868 - val_loss: 1.4233 - val_accuracy: 0.8041
# Epoch 60/100
# 400/400 [==============================] - 17s 43ms/step - loss: 0.0534 - accuracy: 0.9869 - val_loss: 1.3956 - val_accuracy: 0.7653
# Epoch 61/100
# 400/400 [==============================] - 17s 43ms/step - loss: 0.0584 - accuracy: 0.9862 - val_loss: 1.6307 - val_accuracy: 0.7794
# Epoch 62/100
# 400/400 [==============================] - 21s 53ms/step - loss: 0.0432 - accuracy: 0.9906 - val_loss: 1.2028 - val_accuracy: 0.7961
# Epoch 63/100
# 400/400 [==============================] - 17s 44ms/step - loss: 0.0355 - accuracy: 0.9905 - val_loss: 1.1834 - val_accuracy: 0.7774
# Epoch 64/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0484 - accuracy: 0.9882 - val_loss: 1.2321 - val_accuracy: 0.7895
# Epoch 65/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0521 - accuracy: 0.9872 - val_loss: 1.1859 - val_accuracy: 0.8047
# Epoch 66/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0374 - accuracy: 0.9904 - val_loss: 1.2109 - val_accuracy: 0.7811
# Epoch 67/100
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0448 - accuracy: 0.9895 - val_loss: 1.6016 - val_accuracy: 0.7793
# Epoch 68/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0489 - accuracy: 0.9883 - val_loss: 1.1546 - val_accuracy: 0.8193
# Epoch 69/100
# 400/400 [==============================] - 17s 41ms/step - loss: 0.0360 - accuracy: 0.9917 - val_loss: 1.4625 - val_accuracy: 0.7532
# Epoch 70/100
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0405 - accuracy: 0.9900 - val_loss: 1.3671 - val_accuracy: 0.7984
# Epoch 71/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0597 - accuracy: 0.9862 - val_loss: 1.5391 - val_accuracy: 0.7866
# Epoch 72/100
# 400/400 [==============================] - 18s 46ms/step - loss: 0.0306 - accuracy: 0.9909 - val_loss: 1.3796 - val_accuracy: 0.7934
# Epoch 73/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0306 - accuracy: 0.9933 - val_loss: 1.3067 - val_accuracy: 0.7711
# Epoch 74/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0598 - accuracy: 0.9862 - val_loss: 1.1635 - val_accuracy: 0.8068
# Epoch 75/100
# 400/400 [==============================] - 18s 45ms/step - loss: 0.0312 - accuracy: 0.9923 - val_loss: 1.3666 - val_accuracy: 0.8044
# Epoch 76/100
# 400/400 [==============================] - 29s 73ms/step - loss: 0.0504 - accuracy: 0.9886 - val_loss: 1.1785 - val_accuracy: 0.7977
# Epoch 77/100
# 400/400 [==============================] - 29s 72ms/step - loss: 0.0416 - accuracy: 0.9900 - val_loss: 1.1406 - val_accuracy: 0.7863
# Epoch 78/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0309 - accuracy: 0.9914 - val_loss: 1.2082 - val_accuracy: 0.7715
# Epoch 79/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0345 - accuracy: 0.9910 - val_loss: 1.4060 - val_accuracy: 0.8099
# Epoch 80/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0420 - accuracy: 0.9904 - val_loss: 1.1609 - val_accuracy: 0.8009
# Epoch 81/100
# 400/400 [==============================] - 22s 55ms/step - loss: 0.0384 - accuracy: 0.9901 - val_loss: 1.3435 - val_accuracy: 0.8078
# Epoch 82/100
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0384 - accuracy: 0.9905 - val_loss: 1.2726 - val_accuracy: 0.7811
# Epoch 83/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0351 - accuracy: 0.9904 - val_loss: 1.3230 - val_accuracy: 0.8030
# Epoch 84/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0377 - accuracy: 0.9918 - val_loss: 1.1292 - val_accuracy: 0.8014
# Epoch 85/100
# 400/400 [==============================] - 17s 44ms/step - loss: 0.0389 - accuracy: 0.9905 - val_loss: 1.3460 - val_accuracy: 0.8146
# Epoch 86/100
# 400/400 [==============================] - 17s 43ms/step - loss: 0.0315 - accuracy: 0.9922 - val_loss: 1.3789 - val_accuracy: 0.7991
# Epoch 87/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0320 - accuracy: 0.9916 - val_loss: 1.4025 - val_accuracy: 0.7892
# Epoch 88/100
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0406 - accuracy: 0.9905 - val_loss: 1.1783 - val_accuracy: 0.8087
# Epoch 89/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0319 - accuracy: 0.9925 - val_loss: 1.2812 - val_accuracy: 0.8023
# Epoch 90/100
# 400/400 [==============================] - 17s 43ms/step - loss: 0.0328 - accuracy: 0.9923 - val_loss: 1.7433 - val_accuracy: 0.7749
# Epoch 91/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0476 - accuracy: 0.9910 - val_loss: 1.3636 - val_accuracy: 0.7809
# Epoch 92/100
# 400/400 [==============================] - 18s 45ms/step - loss: 0.0374 - accuracy: 0.9912 - val_loss: 1.1318 - val_accuracy: 0.8016
# Epoch 93/100
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0287 - accuracy: 0.9927 - val_loss: 1.3584 - val_accuracy: 0.7987
# Epoch 94/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0237 - accuracy: 0.9935 - val_loss: 1.4284 - val_accuracy: 0.8086
# Epoch 95/100
# 400/400 [==============================] - 18s 44ms/step - loss: 0.0269 - accuracy: 0.9942 - val_loss: 1.4822 - val_accuracy: 0.7941
# Epoch 96/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0471 - accuracy: 0.9902 - val_loss: 1.6146 - val_accuracy: 0.7969
# Epoch 97/100
# 400/400 [==============================] - 16s 41ms/step - loss: 0.0450 - accuracy: 0.9892 - val_loss: 1.4392 - val_accuracy: 0.8152
# Epoch 98/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0434 - accuracy: 0.9904 - val_loss: 1.4031 - val_accuracy: 0.7998
# Epoch 99/100
# 400/400 [==============================] - 17s 42ms/step - loss: 0.0381 - accuracy: 0.9918 - val_loss: 1.4725 - val_accuracy: 0.7800
# Epoch 100/100
# 400/400 [==============================] - 17s 43ms/step - loss: 0.0363 - accuracy: 0.9923 - val_loss: 1.3630 - val_accuracy: 0.8063

# %%
def plot_loss(history):
    """エポックごとの損失関数をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    # 損失関数の履歴を取得
    loss_train = history.history["loss"]
    loss_val = history.history["val_loss"]

    # 損失関数をプロット
    epochs=range(1,len(history.history["loss"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs,loss_train,label="Training loss")
    plt.plot(epochs,loss_val,label="Validation loss")
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
def plot_acc(history):
    """エポックごとの正解率をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    acc_train = history.history['accuracy']
    acc_val = history.history['val_accuracy']
    epochs = range(1,len(history.history["accuracy"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs, acc_train, 'g', label='Training accuracy')
    plt.plot(epochs, acc_val, 'b', label='Validation accuracy')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
# 損失関数の描画
plot_loss(history)

# %%
# 正解率を描画
plot_acc(history)

# %%
# modelの評価
scores = model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 1.4736 - accuracy: 0.8108
