# %% [markdown]
# # 最適化アルゴリズムの比較
# このノートではニューラルネットワークの最適化アルゴリズムの比較を行う. データセットは`fashion_mnist`を用いる.
#
#
# Fashion MNIST https://www.tensorflow.org/api_docs/python/tf/keras/datasets/fashion_mnist/load_data?hl=ja
#
# 28x28の画像データで次の10種類の衣類のいずれかに分類される. 訓練データは60000件, テストデータは10000件ある.
#
# 0. T-shirt/top
# 1. Trouser
# 2. Pullover
# 3. Dress
# 4. Coat
# 5. Sandal
# 6. Shirt
# 7. Sneaker
# 8. Bag
# 9. Ankle boot
#
# 比較するアルゴリズムは次の5つである.
# 1. SGD
# 2. RMSprop
# 3. Adagrad
# 4. Adadelta
# 5. Adam

# %%
# データのロード
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 21s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 3s 1us/step

# %%
# データセットの大きさ確認
print(x_train.shape) # 訓練データのサイズ
print(x_test.shape) # テストデータのサイズ
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
# データの整形
from tensorflow.keras.utils import to_categorical

# (28,28)を(1,784)に変換して色を(0~255)から(0～1)にscaling
x_train = x_train.reshape(-1, 784) / 255
x_test = x_test.reshape(-1, 784) /255
#(0~9)のラベルをone-hot encordinh
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# モデル構築
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout

def set_model(optimizer):
    """最適化アルゴリズムの違うモデルを生成する関数
    
    Args:
    optimizaer(str) : 最適化アルゴリズム名
    
    Returns:
    model : 生成したモデル
    """
    # モデルの容器を作成
    model = Sequential()
    # layerを設定
    model.add(Dense(512, input_shape=(784,), activation='relu', kernel_initializer='he_normal'))
    model.add(Dense(256, activation='relu', kernel_initializer='he_normal'))
    model.add(Dense(128, activation='relu', kernel_initializer='he_normal'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu', kernel_initializer='he_normal'))
    model.add(Dense(32, activation='relu', kernel_initializer='he_normal'))
    model.add(Dense(10, activation='softmax'))
    # 損失関数, 最適化手法, 評価関数を設定
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
# すべての初期値で実行
sgd_model = set_model("SGD")
rms_model = set_model("RMSprop")
adagrad_model = set_model("AdaGrad")
adadelta_model = set_model("Adadelta")
adam_model = set_model("Adam")

# %%
# 学習
from tensorflow.keras.callbacks import EarlyStopping

# patience 指定したepoch数改善がないと訓練を停止する.
early_stopping = EarlyStopping(patience=10, verbose=1)

sgd_history = sgd_model.fit(x_train, y_train, batch_size=1000, verbose=2, epochs=30, validation_data=(x_test, y_test), callbacks=[early_stopping])
rms_history = rms_model.fit(x_train, y_train, batch_size=1000, verbose=2, epochs=30, validation_data=(x_test, y_test), callbacks=[early_stopping])
adagrad_history = adagrad_model.fit(x_train, y_train, batch_size=1000, verbose=2, epochs=30, validation_data=(x_test, y_test), callbacks=[early_stopping])
adadelta_history = adadelta_model.fit(x_train, y_train, batch_size=1000, verbose=2, epochs=30, validation_data=(x_test, y_test), callbacks=[early_stopping])
adam_history = adam_model.fit(x_train, y_train, batch_size=1000, verbose=2, epochs=30, validation_data=(x_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 60/60 - 0s - loss: 0.5305 - accuracy: 0.8181 - val_loss: 0.4905 - val_accuracy: 0.8312
# Epoch 2/30
# 60/60 - 0s - loss: 0.5204 - accuracy: 0.8219 - val_loss: 0.4844 - val_accuracy: 0.8322
# Epoch 3/30
# 60/60 - 0s - loss: 0.5130 - accuracy: 0.8228 - val_loss: 0.4783 - val_accuracy: 0.8341
# Epoch 4/30
# 60/60 - 0s - loss: 0.5084 - accuracy: 0.8260 - val_loss: 0.4773 - val_accuracy: 0.8346
# Epoch 5/30
# 60/60 - 0s - loss: 0.5007 - accuracy: 0.8262 - val_loss: 0.4705 - val_accuracy: 0.8379
# Epoch 6/30
# 60/60 - 0s - loss: 0.4941 - accuracy: 0.8289 - val_loss: 0.4670 - val_accuracy: 0.8363
# Epoch 7/30
# 60/60 - 0s - loss: 0.4905 - accuracy: 0.8303 - val_loss: 0.4636 - val_accuracy: 0.8376
# Epoch 8/30
# 60/60 - 0s - loss: 0.4850 - accuracy: 0.8327 - val_loss: 0.4598 - val_accuracy: 0.8390
# Epoch 9/30
# 60/60 - 0s - loss: 0.4814 - accuracy: 0.8339 - val_loss: 0.4540 - val_accuracy: 0.8402
# Epoch 10/30
# 60/60 - 0s - loss: 0.4760 - accuracy: 0.8354 - val_loss: 0.4531 - val_accuracy: 0.8387
# Epoch 11/30
# 60/60 - 0s - loss: 0.4715 - accuracy: 0.8352 - val_loss: 0.4506 - val_accuracy: 0.8418
# Epoch 12/30
# 60/60 - 0s - loss: 0.4680 - accuracy: 0.8380 - val_loss: 0.4467 - val_accuracy: 0.8419
# Epoch 13/30
# 60/60 - 0s - loss: 0.4638 - accuracy: 0.8384 - val_loss: 0.4427 - val_accuracy: 0.8437
# Epoch 14/30
# 60/60 - 0s - loss: 0.4593 - accuracy: 0.8383 - val_loss: 0.4429 - val_accuracy: 0.8431
# Epoch 15/30
# 60/60 - 0s - loss: 0.4579 - accuracy: 0.8411 - val_loss: 0.4392 - val_accuracy: 0.8435
# Epoch 16/30
# 60/60 - 0s - loss: 0.4536 - accuracy: 0.8415 - val_loss: 0.4367 - val_accuracy: 0.8453
# Epoch 17/30
# 60/60 - 0s - loss: 0.4516 - accuracy: 0.8428 - val_loss: 0.4340 - val_accuracy: 0.8473
# Epoch 18/30
# 60/60 - 0s - loss: 0.4459 - accuracy: 0.8442 - val_loss: 0.4342 - val_accuracy: 0.8456
# Epoch 19/30
# 60/60 - 0s - loss: 0.4436 - accuracy: 0.8450 - val_loss: 0.4346 - val_accuracy: 0.8464
# Epoch 20/30
# 60/60 - 0s - loss: 0.4414 - accuracy: 0.8458 - val_loss: 0.4290 - val_accuracy: 0.8482
# Epoch 21/30
# 60/60 - 0s - loss: 0.4394 - accuracy: 0.8464 - val_loss: 0.4279 - val_accuracy: 0.8480
# Epoch 22/30
# 60/60 - 0s - loss: 0.4336 - accuracy: 0.8473 - val_loss: 0.4248 - val_accuracy: 0.8480
# Epoch 23/30
# 60/60 - 0s - loss: 0.4310 - accuracy: 0.8479 - val_loss: 0.4258 - val_accuracy: 0.8491
# Epoch 24/30
# 60/60 - 0s - loss: 0.4310 - accuracy: 0.8490 - val_loss: 0.4241 - val_accuracy: 0.8493
# Epoch 25/30
# 60/60 - 0s - loss: 0.4277 - accuracy: 0.8487 - val_loss: 0.4203 - val_accuracy: 0.8499
# Epoch 26/30
# 60/60 - 0s - loss: 0.4244 - accuracy: 0.8513 - val_loss: 0.4194 - val_accuracy: 0.8499
# Epoch 27/30
# 60/60 - 0s - loss: 0.4249 - accuracy: 0.8515 - val_loss: 0.4176 - val_accuracy: 0.8493
# Epoch 28/30
# 60/60 - 0s - loss: 0.4197 - accuracy: 0.8521 - val_loss: 0.4178 - val_accuracy: 0.8514
# Epoch 29/30
# 60/60 - 0s - loss: 0.4186 - accuracy: 0.8537 - val_loss: 0.4166 - val_accuracy: 0.8504
# Epoch 30/30
# 60/60 - 0s - loss: 0.4154 - accuracy: 0.8544 - val_loss: 0.4131 - val_accuracy: 0.8516
# Epoch 1/30
# 60/60 - 0s - loss: 0.2263 - accuracy: 0.9133 - val_loss: 0.3395 - val_accuracy: 0.8827
# Epoch 2/30
# 60/60 - 0s - loss: 0.2244 - accuracy: 0.9145 - val_loss: 0.3523 - val_accuracy: 0.8812
# Epoch 3/30
# 60/60 - 0s - loss: 0.2174 - accuracy: 0.9175 - val_loss: 0.3677 - val_accuracy: 0.8907
# Epoch 4/30
# 60/60 - 0s - loss: 0.2143 - accuracy: 0.9177 - val_loss: 0.3884 - val_accuracy: 0.8806
# Epoch 5/30
# 60/60 - 0s - loss: 0.2055 - accuracy: 0.9211 - val_loss: 0.4097 - val_accuracy: 0.8706
# Epoch 6/30
# 60/60 - 0s - loss: 0.2008 - accuracy: 0.9227 - val_loss: 0.3575 - val_accuracy: 0.8877
# Epoch 7/30
# 60/60 - 0s - loss: 0.1972 - accuracy: 0.9245 - val_loss: 0.3254 - val_accuracy: 0.8988
# Epoch 8/30
# 60/60 - 0s - loss: 0.1926 - accuracy: 0.9265 - val_loss: 0.3712 - val_accuracy: 0.8923
# Epoch 9/30
# 60/60 - 0s - loss: 0.1915 - accuracy: 0.9266 - val_loss: 0.3384 - val_accuracy: 0.8894
# Epoch 10/30
# 60/60 - 0s - loss: 0.1871 - accuracy: 0.9290 - val_loss: 0.3539 - val_accuracy: 0.8929
# Epoch 11/30
# 60/60 - 0s - loss: 0.1808 - accuracy: 0.9296 - val_loss: 0.3858 - val_accuracy: 0.8939
# Epoch 12/30
# 60/60 - 0s - loss: 0.1835 - accuracy: 0.9318 - val_loss: 0.3531 - val_accuracy: 0.8951
# Epoch 13/30
# 60/60 - 0s - loss: 0.1698 - accuracy: 0.9338 - val_loss: 0.3766 - val_accuracy: 0.8905
# Epoch 14/30
# 60/60 - 0s - loss: 0.1711 - accuracy: 0.9347 - val_loss: 0.4288 - val_accuracy: 0.8822
# Epoch 15/30
# 60/60 - 0s - loss: 0.1644 - accuracy: 0.9361 - val_loss: 0.3739 - val_accuracy: 0.8943
# Epoch 16/30
# 60/60 - 0s - loss: 0.1624 - accuracy: 0.9387 - val_loss: 0.4822 - val_accuracy: 0.8804
# Epoch 17/30
# 60/60 - 0s - loss: 0.1592 - accuracy: 0.9389 - val_loss: 0.4194 - val_accuracy: 0.8835
# Epoch 00017: early stopping
# Epoch 1/30
# 60/60 - 0s - loss: 0.8262 - accuracy: 0.7061 - val_loss: 0.7374 - val_accuracy: 0.7471
# Epoch 2/30
# 60/60 - 0s - loss: 0.8129 - accuracy: 0.7120 - val_loss: 0.7285 - val_accuracy: 0.7487
# Epoch 3/30
# 60/60 - 0s - loss: 0.8037 - accuracy: 0.7142 - val_loss: 0.7195 - val_accuracy: 0.7514
# Epoch 4/30
# 60/60 - 0s - loss: 0.7923 - accuracy: 0.7216 - val_loss: 0.7106 - val_accuracy: 0.7532
# Epoch 5/30
# 60/60 - 0s - loss: 0.7830 - accuracy: 0.7235 - val_loss: 0.7019 - val_accuracy: 0.7590
# Epoch 6/30
# 60/60 - 0s - loss: 0.7755 - accuracy: 0.7274 - val_loss: 0.6940 - val_accuracy: 0.7618
# Epoch 7/30
# 60/60 - 0s - loss: 0.7610 - accuracy: 0.7363 - val_loss: 0.6868 - val_accuracy: 0.7659
# Epoch 8/30
# 60/60 - 0s - loss: 0.7529 - accuracy: 0.7360 - val_loss: 0.6798 - val_accuracy: 0.7671
# Epoch 9/30
# 60/60 - 0s - loss: 0.7451 - accuracy: 0.7415 - val_loss: 0.6718 - val_accuracy: 0.7737
# Epoch 10/30
# 60/60 - 0s - loss: 0.7368 - accuracy: 0.7436 - val_loss: 0.6654 - val_accuracy: 0.7744
# Epoch 11/30
# 60/60 - 0s - loss: 0.7298 - accuracy: 0.7475 - val_loss: 0.6587 - val_accuracy: 0.7768
# Epoch 12/30
# 60/60 - 0s - loss: 0.7247 - accuracy: 0.7491 - val_loss: 0.6525 - val_accuracy: 0.7798
# Epoch 13/30
# 60/60 - 0s - loss: 0.7149 - accuracy: 0.7526 - val_loss: 0.6466 - val_accuracy: 0.7799
# Epoch 14/30
# 60/60 - 0s - loss: 0.7076 - accuracy: 0.7561 - val_loss: 0.6416 - val_accuracy: 0.7839
# Epoch 15/30
# 60/60 - 0s - loss: 0.6986 - accuracy: 0.7600 - val_loss: 0.6360 - val_accuracy: 0.7881
# Epoch 16/30
# 60/60 - 0s - loss: 0.6945 - accuracy: 0.7613 - val_loss: 0.6318 - val_accuracy: 0.7862
# Epoch 17/30
# 60/60 - 0s - loss: 0.6880 - accuracy: 0.7619 - val_loss: 0.6254 - val_accuracy: 0.7894
# Epoch 18/30
# 60/60 - 0s - loss: 0.6821 - accuracy: 0.7671 - val_loss: 0.6206 - val_accuracy: 0.7905
# Epoch 19/30
# 60/60 - 0s - loss: 0.6769 - accuracy: 0.7697 - val_loss: 0.6164 - val_accuracy: 0.7915
# Epoch 20/30
# 60/60 - 0s - loss: 0.6679 - accuracy: 0.7707 - val_loss: 0.6113 - val_accuracy: 0.7953
# Epoch 21/30
# 60/60 - 0s - loss: 0.6647 - accuracy: 0.7729 - val_loss: 0.6066 - val_accuracy: 0.7948
# Epoch 22/30
# 60/60 - 0s - loss: 0.6581 - accuracy: 0.7754 - val_loss: 0.6028 - val_accuracy: 0.7976
# Epoch 23/30
# 60/60 - 0s - loss: 0.6537 - accuracy: 0.7768 - val_loss: 0.5982 - val_accuracy: 0.7968
# Epoch 24/30
# 60/60 - 0s - loss: 0.6508 - accuracy: 0.7790 - val_loss: 0.5939 - val_accuracy: 0.8004
# Epoch 25/30
# 60/60 - 0s - loss: 0.6411 - accuracy: 0.7817 - val_loss: 0.5903 - val_accuracy: 0.8022
# Epoch 26/30
# 60/60 - 0s - loss: 0.6415 - accuracy: 0.7809 - val_loss: 0.5859 - val_accuracy: 0.8019
# Epoch 27/30
# 60/60 - 0s - loss: 0.6341 - accuracy: 0.7839 - val_loss: 0.5823 - val_accuracy: 0.8033
# Epoch 28/30
# 60/60 - 0s - loss: 0.6307 - accuracy: 0.7861 - val_loss: 0.5793 - val_accuracy: 0.8045
# Epoch 29/30
# 60/60 - 0s - loss: 0.6249 - accuracy: 0.7876 - val_loss: 0.5757 - val_accuracy: 0.8063
# Epoch 30/30
# 60/60 - 0s - loss: 0.6218 - accuracy: 0.7877 - val_loss: 0.5719 - val_accuracy: 0.8073
# Epoch 1/30
# 60/60 - 0s - loss: 1.7722 - accuracy: 0.3993 - val_loss: 1.6442 - val_accuracy: 0.4788
# Epoch 2/30
# 60/60 - 0s - loss: 1.7471 - accuracy: 0.4067 - val_loss: 1.6152 - val_accuracy: 0.4941
# Epoch 3/30
# 60/60 - 0s - loss: 1.7178 - accuracy: 0.4232 - val_loss: 1.5862 - val_accuracy: 0.5141
# Epoch 4/30
# 60/60 - 0s - loss: 1.6933 - accuracy: 0.4299 - val_loss: 1.5570 - val_accuracy: 0.5333
# Epoch 5/30
# 60/60 - 0s - loss: 1.6676 - accuracy: 0.4414 - val_loss: 1.5281 - val_accuracy: 0.5508
# Epoch 6/30
# 60/60 - 0s - loss: 1.6444 - accuracy: 0.4500 - val_loss: 1.4993 - val_accuracy: 0.5643
# Epoch 7/30
# 60/60 - 0s - loss: 1.6178 - accuracy: 0.4624 - val_loss: 1.4713 - val_accuracy: 0.5742
# Epoch 8/30
# 60/60 - 0s - loss: 1.5920 - accuracy: 0.4720 - val_loss: 1.4434 - val_accuracy: 0.5838
# Epoch 9/30
# 60/60 - 0s - loss: 1.5681 - accuracy: 0.4820 - val_loss: 1.4161 - val_accuracy: 0.5939
# Epoch 10/30
# 60/60 - 0s - loss: 1.5431 - accuracy: 0.4922 - val_loss: 1.3895 - val_accuracy: 0.6004
# Epoch 11/30
# 60/60 - 0s - loss: 1.5147 - accuracy: 0.5038 - val_loss: 1.3632 - val_accuracy: 0.6077
# Epoch 12/30
# 60/60 - 0s - loss: 1.4937 - accuracy: 0.5130 - val_loss: 1.3375 - val_accuracy: 0.6140
# Epoch 13/30
# 60/60 - 0s - loss: 1.4707 - accuracy: 0.5220 - val_loss: 1.3126 - val_accuracy: 0.6211
# Epoch 14/30
# 60/60 - 0s - loss: 1.4477 - accuracy: 0.5293 - val_loss: 1.2887 - val_accuracy: 0.6280
# Epoch 15/30
# 60/60 - 0s - loss: 1.4271 - accuracy: 0.5391 - val_loss: 1.2657 - val_accuracy: 0.6358
# Epoch 16/30
# 60/60 - 0s - loss: 1.4040 - accuracy: 0.5480 - val_loss: 1.2433 - val_accuracy: 0.6436
# Epoch 17/30
# 60/60 - 0s - loss: 1.3826 - accuracy: 0.5586 - val_loss: 1.2220 - val_accuracy: 0.6509
# Epoch 18/30
# 60/60 - 0s - loss: 1.3629 - accuracy: 0.5665 - val_loss: 1.2014 - val_accuracy: 0.6569
# Epoch 19/30
# 60/60 - 0s - loss: 1.3427 - accuracy: 0.5722 - val_loss: 1.1819 - val_accuracy: 0.6656
# Epoch 20/30
# 60/60 - 0s - loss: 1.3243 - accuracy: 0.5792 - val_loss: 1.1631 - val_accuracy: 0.6703
# Epoch 21/30
# 60/60 - 0s - loss: 1.3020 - accuracy: 0.5872 - val_loss: 1.1452 - val_accuracy: 0.6760
# Epoch 22/30
# 60/60 - 0s - loss: 1.2903 - accuracy: 0.5897 - val_loss: 1.1281 - val_accuracy: 0.6821
# Epoch 23/30
# 60/60 - 0s - loss: 1.2702 - accuracy: 0.6018 - val_loss: 1.1118 - val_accuracy: 0.6868
# Epoch 24/30
# 60/60 - 0s - loss: 1.2536 - accuracy: 0.6052 - val_loss: 1.0958 - val_accuracy: 0.6898
# Epoch 25/30
# 60/60 - 0s - loss: 1.2397 - accuracy: 0.6114 - val_loss: 1.0808 - val_accuracy: 0.6916
# Epoch 26/30
# 60/60 - 0s - loss: 1.2218 - accuracy: 0.6191 - val_loss: 1.0663 - val_accuracy: 0.6933
# Epoch 27/30
# 60/60 - 0s - loss: 1.2098 - accuracy: 0.6227 - val_loss: 1.0528 - val_accuracy: 0.6943
# Epoch 28/30
# 60/60 - 0s - loss: 1.1934 - accuracy: 0.6264 - val_loss: 1.0398 - val_accuracy: 0.6966
# Epoch 29/30
# 60/60 - 0s - loss: 1.1794 - accuracy: 0.6325 - val_loss: 1.0272 - val_accuracy: 0.6976
# Epoch 30/30
# 60/60 - 0s - loss: 1.1691 - accuracy: 0.6341 - val_loss: 1.0153 - val_accuracy: 0.6981
# Epoch 1/30
# 60/60 - 0s - loss: 0.1826 - accuracy: 0.9306 - val_loss: 0.3317 - val_accuracy: 0.8936
# Epoch 2/30
# 60/60 - 0s - loss: 0.1757 - accuracy: 0.9340 - val_loss: 0.3332 - val_accuracy: 0.8958
# Epoch 3/30
# 60/60 - 0s - loss: 0.1698 - accuracy: 0.9363 - val_loss: 0.3417 - val_accuracy: 0.8936
# Epoch 4/30
# 60/60 - 0s - loss: 0.1722 - accuracy: 0.9357 - val_loss: 0.3470 - val_accuracy: 0.8923
# Epoch 5/30
# 60/60 - 0s - loss: 0.1612 - accuracy: 0.9393 - val_loss: 0.3460 - val_accuracy: 0.8982
# Epoch 6/30
# 60/60 - 0s - loss: 0.1612 - accuracy: 0.9394 - val_loss: 0.3440 - val_accuracy: 0.8981
# Epoch 7/30
# 60/60 - 0s - loss: 0.1500 - accuracy: 0.9438 - val_loss: 0.3421 - val_accuracy: 0.8911
# Epoch 8/30
# 60/60 - 0s - loss: 0.1445 - accuracy: 0.9450 - val_loss: 0.3558 - val_accuracy: 0.8958
# Epoch 9/30
# 60/60 - 0s - loss: 0.1424 - accuracy: 0.9467 - val_loss: 0.3705 - val_accuracy: 0.8971
# Epoch 10/30
# 60/60 - 0s - loss: 0.1413 - accuracy: 0.9473 - val_loss: 0.3707 - val_accuracy: 0.8936
# Epoch 11/30
# 60/60 - 0s - loss: 0.1402 - accuracy: 0.9471 - val_loss: 0.3526 - val_accuracy: 0.9012
# Epoch 00011: early stopping

# %%
def calc_score(model):
    """テストセットの正解率と損失関数を表示する関数
    
    Args:
    model : 正解率と損失関数を計算するモデル
    
    Returns:
    None
    """
    score = model.evaluate(x_test, y_test, verbose=0)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])

# %%
# テストセットの正解率と損失関数を表示
print("SGD")
calc_score(sgd_model)
print("RMSprop")
calc_score(rms_model)
print("Adagrad")
calc_score(adagrad_model)
print("AdaDelta")
calc_score(adadelta_model)
print("Adam")
calc_score(adam_model)
# Out:
# SGD
# Test loss: 0.4131484925746918
# Test accuracy: 0.8515999913215637
# RMSprop
# Test loss: 0.4193887710571289
# Test accuracy: 0.8834999799728394
# Adagrad
# Test loss: 0.5719289183616638
# Test accuracy: 0.8072999715805054
# AdaDelta
# Test loss: 1.0153038501739502
# Test accuracy: 0.6980999708175659
# Adam
# Test loss: 0.35262855887413025
# Test accuracy: 0.901199996471405

# %%
def plot_loss(history):
    """エポックごとの損失関数をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    # 損失関数の履歴を取得
    loss_train = history.history["loss"]
    loss_val = history.history["val_loss"]

    # 損失関数をプロット
    epochs=range(1,len(history.history["loss"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs,loss_train,label="Training loss")
    plt.plot(epochs,loss_val,label="Validation loss")
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()

# %%
print("SGD")
plot_loss(sgd_history)
print("RMSprop")
plot_loss(rms_history)
print("Adagrad")
plot_loss(adagrad_history)
print("AdaDelta")
plot_loss(adadelta_history)
print("Adam")
plot_loss(adam_history)
# Out:
# SGD
# RMSprop
# Adagrad
# AdaDelta
# Adam

# %%
def plot_acc(history):
    """エポックごとの正解率をプロットする関数
    
    Args:
    history : fittingの履歴
    
    Returns:
    None
    """
    acc_train = history.history['accuracy']
    acc_val = history.history['val_accuracy']
    epochs = range(1,len(history.history["accuracy"])+1)
    plt.figure(facecolor="white")
    plt.plot(epochs, acc_train, 'g', label='Training accuracy')
    plt.plot(epochs, acc_val, 'b', label='Validation accuracy')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
print("SGD")
plot_acc(sgd_history)
print("RMSprop")
plot_acc(rms_history)
print("Adagrad")
plot_acc(adagrad_history)
print("AdaDelta")
plot_acc(adadelta_history)
print("Adam")
plot_acc(adam_history)
# Out:
# SGD
# RMSprop
# Adagrad
# AdaDelta
# Adam
