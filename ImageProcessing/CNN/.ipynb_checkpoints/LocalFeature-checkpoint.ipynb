# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # 空間フィルタリング

# %% [markdown]
# ## 平均化フィルタ

# %%
# 画像の読み込み
img = cv2.imread("sample.jpg", cv2.COLOR_BGR2RGB)
plt.imshow(img)
